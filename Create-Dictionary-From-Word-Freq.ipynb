# %%
import pandas as pd
import sqlite3
import json
import pickle

# %% [markdown]
# Create connection to database and look at structure

# %%
conn_lyrics = sqlite3.connect('../Data/mxm_dataset.db')
res = conn_lyrics.execute("Select * FROM sqlite_master where type = 'table'")
res.fetchall()
# Out:
# [('table', 'words', 'words', 2, 'CREATE TABLE words (word TEXT PRIMARY KEY)'),
#  ('table',
#   'lyrics',
#   'lyrics',
#   4,
#   'CREATE TABLE lyrics (track_id, mxm_tid INT, word TEXT, count INT, is_test INT, FOREIGN KEY(word) REFERENCES words(word))')]

# %%
# create dataframe from lyrics. 
track_info = pd.read_sql("SELECT track_id, word, count FROM lyrics", con = conn_lyrics)

# %%
# get unique track
tracks = track_info.drop_duplicates(subset='track_id')
# reset index since it retains original ind
tracks.index=range(len(tracks))
# look at the first five records. We don't care about word or count
tracks.head()
# Out:
#              track_id word  count
# 0  TRAAAAV128F421A322    i      6
# 1  TRAAABD128F429CF47    i     10
# 2  TRAAAED128E0783FAB    i     28
# 3  TRAAAEF128F4273421    i      5
# 4  TRAAAEW128F42930C0    i      4

# %%
len(tracks['track_id'])
# Out:
# 237662

# %%
my_dict = {}

## Change the second number in range to len(tracks['track_id']) for all the records. 
## Keeping it shorter for now to reduce processing time.

for i in range(0,100): 
    # assign the value of the track at current index to current track
    current_track = tracks.track_id[i]

    # pull the lyrics for that track and store it in a list
    res = conn_lyrics.execute("SELECT word FROM lyrics WHERE track_id = ?", [current_track])
    results = res.fetchall()
    # extract the word from results (otherwise it returns it AS ('word',))
    li = [x[0]for x in results]
    # add track and lyrics to dictionary
    my_dict[current_track] = li
    #my_dict = {current_track : li}

# %%
len(my_dict)
# Out:
# 100

# %% [markdown]
# How should this data be stored? http://stackoverflow.com/questions/7100125/storing-python-dictionaries

# %%
# save to json file in same directory
import json
with open('lyrics_dict.json', 'w') as fp:
    # arguments can include indent=n or None, sort_keys = True
    json.dump(my_dict, fp, indent=None)

# %%
with open('lyrics_dict.json', 'r') as fp:
    data_json = json.load(fp)

# %%
# don't include this if posting to github

#data_json
# Out:
# {'TRAAAAV128F421A322': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'are',
#   'we',
#   'am',
#   'will',
#   'for',
#   'be',
#   'have',
#   'so',
#   'this',
#   'like',
#   'de',
#   'up',
#   'was',
#   'if',
#   'got',
#   'would',
#   'been',
#   'these',
#   'seem',
#   'someon',
#   'understand',
#   'pass',
#   'river',
#   'met',
#   'piec',
#   'damn',
#   'worth',
#   'flesh',
#   'grace',
#   'poor',
#   'somehow',
#   'ignor',
#   'passion',
#   'tide',
#   'season',
#   'seed',
#   'resist',
#   'order',
#   'piti',
#   'fashion',
#   'grant',
#   'captur',
#   'ici',
#   'soil',
#   'patienc',
#   'social',
#   'highest',
#   'slice',
#   'leaf',
#   'lifeless',
#   'arrang',
#   'wilder',
#   'shark',
#   'devast',
#   'element'],
#  'TRAAABD128F429CF47': ['i',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'your',
#   'that',
#   'do',
#   'are',
#   'for',
#   'no',
#   'have',
#   'so',
#   'know',
#   'but',
#   'what',
#   'when',
#   'time',
#   'can',
#   'there',
#   'la',
#   'get',
#   'got',
#   'never',
#   'feel',
#   'want',
#   'would',
#   'day',
#   'away',
#   'yeah',
#   'heart',
#   'could',
#   'need',
#   'our',
#   'look',
#   'where',
#   'thing',
#   'think',
#   'live',
#   'onli',
#   'tri',
#   'keep',
#   'dream',
#   'wanna',
#   'find',
#   'hear',
#   'believ',
#   'everyth',
#   'someth',
#   'insid',
#   'chang',
#   'soul',
#   'new',
#   'start',
#   'pleas',
#   'true',
#   'while',
#   'deep',
#   'beat',
#   'after',
#   'fade',
#   'wast',
#   'trust',
#   'alreadi',
#   'style',
#   'asleep',
#   'wors',
#   'goal'],
#  'TRAAAED128E0783FAB': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'do',
#   'on',
#   'are',
#   'am',
#   'will',
#   'for',
#   'be',
#   'have',
#   'love',
#   'so',
#   'this',
#   'but',
#   'just',
#   'when',
#   'like',
#   'time',
#   'come',
#   'go',
#   'one',
#   'out',
#   'down',
#   'if',
#   'got',
#   'from',
#   'feel',
#   'make',
#   'way',
#   'take',
#   'day',
#   'by',
#   'her',
#   'heart',
#   'could',
#   'look',
#   'where',
#   'more',
#   'been',
#   'who',
#   'through',
#   'onli',
#   'tri',
#   'whi',
#   'dream',
#   'well',
#   'an',
#   'long',
#   'girl',
#   'find',
#   'good',
#   'about',
#   'some',
#   'littl',
#   'wait',
#   'run',
#   'walk',
#   'gone',
#   'someth',
#   'befor',
#   'much',
#   'anoth',
#   'new',
#   'tonight',
#   'burn',
#   'thought',
#   'realli',
#   'hard',
#   'care',
#   'put',
#   'seem',
#   'mine',
#   'fire',
#   'someon',
#   'while',
#   'doe',
#   'smile',
#   'open',
#   'door',
#   'mayb',
#   'may',
#   'sometim',
#   'lone',
#   'chanc',
#   'air',
#   'water',
#   'readi',
#   'past',
#   'happen',
#   'pretti',
#   'differ',
#   'faith',
#   'search',
#   'flame',
#   'piec',
#   'cos',
#   'meant',
#   'higher',
#   'edg',
#   'surpris',
#   'person',
#   'twice',
#   'noon',
#   'thin',
#   'celebr',
#   'inspir',
#   'advic',
#   'ideal'],
#  'TRAAAEF128F4273421': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'not',
#   'is',
#   'of',
#   'that',
#   'do',
#   'are',
#   'for',
#   'know',
#   'this',
#   'with',
#   'when',
#   'can',
#   'she',
#   'if',
#   'got',
#   'from',
#   'feel',
#   'let',
#   'would',
#   'her',
#   'eye',
#   'world',
#   'right',
#   'think',
#   'through',
#   'or',
#   'wo',
#   'girl',
#   'everi',
#   'had',
#   'has',
#   'someth',
#   'tonight',
#   'old',
#   'boy',
#   'mine',
#   'someon',
#   'star',
#   'while',
#   'wish',
#   'smile',
#   'shine',
#   'yourself',
#   'ask',
#   'white',
#   'three',
#   'send',
#   'treat',
#   'relax',
#   'tip',
#   'pearl',
#   'curl',
#   'adam'],
#  'TRAAAEW128F42930C0': ['i',
#   'to',
#   'and',
#   'a',
#   'me',
#   'not',
#   'in',
#   'my',
#   'that',
#   'on',
#   'am',
#   'all',
#   'with',
#   'like',
#   'up',
#   'take',
#   'would',
#   'or',
#   'an',
#   'wo',
#   'someth',
#   'stay',
#   'burn',
#   'made',
#   'use',
#   'someon',
#   'those',
#   'breath',
#   'done',
#   'touch',
#   'bodi',
#   'fade',
#   'sad',
#   'stone',
#   'tight',
#   'space',
#   'color',
#   'mess',
#   'tie',
#   'paint',
#   'cast',
#   'fix',
#   'bend',
#   'melt',
#   'grey',
#   'ash',
#   'wire',
#   'liar',
#   'stain',
#   'wet',
#   'mix',
#   'numb',
#   'rust',
#   'burnt',
#   'debt',
#   'lifeless',
#   'dissolv',
#   'mold',
#   'clay',
#   'print',
#   'wax',
#   'ink',
#   'leak'],
#  'TRAAAFD128F92F423A': ['i',
#   'the',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'do',
#   'on',
#   'are',
#   'am',
#   'all',
#   'for',
#   'no',
#   'have',
#   'this',
#   'just',
#   'now',
#   'there',
#   'one',
#   'got',
#   'never',
#   'from',
#   'feel',
#   'way',
#   'take',
#   'would',
#   'away',
#   'how',
#   'could',
#   'world',
#   'caus',
#   'die',
#   'been',
#   'think',
#   'again',
#   'dream',
#   'his',
#   'over',
#   'turn',
#   'then',
#   'walk',
#   'face',
#   'word',
#   'place',
#   'better',
#   'him',
#   'someon',
#   'those',
#   'while',
#   'kill',
#   'done',
#   'matter',
#   'lay',
#   'red',
#   'memori',
#   'tire',
#   'clear',
#   'felt',
#   'secret',
#   'wave',
#   'mouth',
#   'win',
#   'exist',
#   'swear',
#   'none',
#   'ash',
#   'ador',
#   'eras',
#   'worst',
#   'sale',
#   'settl',
#   'seal',
#   'worn',
#   'limb',
#   'concern',
#   'runaway'],
#  'TRAAAGF12903CEC202': ['en',
#   'e',
#   'end',
#   'du',
#   'et',
#   'fine',
#   'som',
#   'n',
#   'ei',
#   'og',
#   'så',
#   'mot',
#   'min',
#   'din',
#   'alt',
#   'inn',
#   'leve',
#   'når',
#   'gi'],
#  'TRAAAHJ128F931194C': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'in',
#   'my',
#   'of',
#   'your',
#   'do',
#   'on',
#   'we',
#   'am',
#   'for',
#   'be',
#   'love',
#   'this',
#   'just',
#   'when',
#   'now',
#   'time',
#   'can',
#   'out',
#   'never',
#   'say',
#   'day',
#   'at',
#   'away',
#   'back',
#   'heart',
#   'here',
#   'how',
#   'world',
#   'onli',
#   'an',
#   'long',
#   'turn',
#   'hand',
#   'walk',
#   'cri',
#   'word',
#   'these',
#   'last',
#   'close',
#   'breath',
#   'wish',
#   'war',
#   'beat',
#   'angel',
#   'reach',
#   'step',
#   'memori',
#   'apart',
#   'speak',
#   'til',
#   'afraid',
#   'wave',
#   'bone',
#   'wing',
#   'rose',
#   'shame',
#   'forgiv',
#   'loud',
#   'sail',
#   'bridg',
#   'dare',
#   'torn',
#   'echo',
#   'sigh',
#   'nake',
#   'sunset',
#   'delight',
#   'thorn',
#   'sharp',
#   'stir',
#   'solitud',
#   'fleet'],
#  'TRAAAHZ128E0799171': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'all',
#   'for',
#   'no',
#   'have',
#   'love',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'when',
#   'like',
#   'now',
#   'time',
#   'can',
#   'come',
#   'go',
#   'up',
#   'one',
#   'they',
#   'out',
#   'down',
#   'get',
#   'was',
#   'see',
#   'got',
#   'never',
#   'from',
#   'feel',
#   'want',
#   'way',
#   'say',
#   'as',
#   'ca',
#   'at',
#   'yeah',
#   'back',
#   'heart',
#   'here',
#   'night',
#   'need',
#   'look',
#   'world',
#   'more',
#   'caus',
#   'right',
#   'been',
#   'tell',
#   'man',
#   'live',
#   'again',
#   'give',
#   'too',
#   'onli',
#   'whi',
#   'dream',
#   'around',
#   'good',
#   'about',
#   'some',
#   'over',
#   'leav',
#   'had',
#   'gone',
#   'stay',
#   'god',
#   'these',
#   'new',
#   'him',
#   'stop',
#   'burn',
#   'sun',
#   'off',
#   'play',
#   'made',
#   'start',
#   'hard',
#   'boy',
#   'put',
#   'name',
#   'same',
#   'fuck',
#   'other',
#   'rememb',
#   'star',
#   'yes',
#   'real',
#   'two',
#   'black',
#   'rock',
#   'shine',
#   'heaven',
#   'work',
#   'big',
#   'street',
#   'came',
#   'till',
#   'deep',
#   'happi',
#   'ai',
#   'best',
#   'listen',
#   'hell',
#   'set',
#   'em',
#   'pass',
#   'fool',
#   'chanc',
#   'part',
#   'nobodi',
#   'game',
#   'though',
#   'each',
#   'young',
#   'readi',
#   'shit',
#   'along',
#   'hit',
#   'happen',
#   'whole',
#   'car',
#   'pray',
#   'gave',
#   'tire',
#   'lot',
#   'sinc',
#   'kid',
#   'nigga',
#   'hot',
#   'bright',
#   'secret',
#   'push',
#   'three',
#   'drop',
#   'wear',
#   'uh',
#   'thank',
#   'catch',
#   'fell',
#   'top',
#   'cover',
#   'write',
#   'number',
#   'lock',
#   'bless',
#   'knock',
#   'four',
#   'check',
#   'famili',
#   'choos',
#   'small',
#   'wit',
#   'swear',
#   'yall',
#   'c',
#   'kept',
#   'busi',
#   'price',
#   'trip',
#   'shoulder',
#   'tune',
#   'pop',
#   'wife',
#   'bite',
#   'west',
#   'block',
#   'g',
#   'direct',
#   'rap',
#   'laid',
#   'clock',
#   'paid',
#   'yellow',
#   'judg',
#   'doubl',
#   'wise',
#   'mom',
#   'older',
#   'motherfuck',
#   'spot',
#   'beach',
#   'aw',
#   'throne',
#   'steadi',
#   'handl',
#   'coast',
#   'mic',
#   'boss',
#   'weed',
#   'presenc',
#   'jail',
#   'grind',
#   'buck',
#   'righteous',
#   'sharp',
#   'playa',
#   'famous',
#   'colder',
#   'file',
#   'local',
#   'process',
#   'bid',
#   'profit'],
#  'TRAAAJG128F9308A25': ['i',
#   'the',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'is',
#   'that',
#   'do',
#   'on',
#   'are',
#   'for',
#   'have',
#   'so',
#   'but',
#   'like',
#   'can',
#   'one',
#   'get',
#   'from',
#   'ca',
#   'here',
#   'need',
#   'world',
#   'die',
#   'give',
#   'too',
#   'tri',
#   'walk',
#   'end',
#   'much',
#   'stand',
#   'old',
#   'without',
#   'pain',
#   'myself',
#   'rain',
#   'cold',
#   'bad',
#   'mani',
#   'goe',
#   'young',
#   'kid',
#   'bleed',
#   'somewher',
#   'bitter',
#   'protect',
#   'hungri',
#   'order',
#   'although',
#   'coat',
#   'helpless',
#   'complain',
#   'defend'],
#  'TRAAAOF128F429C156': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'on',
#   'we',
#   'am',
#   'will',
#   'all',
#   'no',
#   'have',
#   'so',
#   'know',
#   'what',
#   'just',
#   'when',
#   'like',
#   'now',
#   'can',
#   'come',
#   'there',
#   'go',
#   'up',
#   'oh',
#   'one',
#   'they',
#   'out',
#   'was',
#   'see',
#   'got',
#   'from',
#   'he',
#   'feel',
#   'say',
#   'day',
#   'at',
#   'yeah',
#   'back',
#   'our',
#   'look',
#   'right',
#   'man',
#   'onli',
#   'whi',
#   'his',
#   'long',
#   'girl',
#   'some',
#   'over',
#   'littl',
#   'were',
#   'leav',
#   'home',
#   'had',
#   'them',
#   'face',
#   'head',
#   'their',
#   'stay',
#   'place',
#   'better',
#   'last',
#   'him',
#   'tonight',
#   'off',
#   'start',
#   'realli',
#   'even',
#   'put',
#   'seem',
#   'other',
#   'high',
#   'came',
#   'everybodi',
#   'until',
#   'saw',
#   'ha',
#   'heard',
#   'soon',
#   'guess',
#   'full',
#   'king',
#   'tree',
#   'kid',
#   'near',
#   'honey',
#   'perfect',
#   'hair',
#   'knee',
#   'share',
#   'top',
#   'kick',
#   'guy',
#   'whoa',
#   'million',
#   'jump',
#   'snow',
#   'everywher',
#   'sand',
#   'hello',
#   'state',
#   'school',
#   'scene',
#   'spread',
#   'luck',
#   'pop',
#   'doin',
#   'huh',
#   'ooo',
#   'saturday',
#   'woo',
#   'beach',
#   'scratch',
#   'whip',
#   'hop',
#   'aah',
#   'hmm',
#   'bop',
#   'wow',
#   'flip',
#   'blowin',
#   'muscl',
#   'filthi',
#   'local',
#   'wah',
#   'oooo',
#   'yah',
#   'aaah',
#   'jumpin',
#   'eventu',
#   'comb'],
#  'TRAAARJ128F9320760': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'your',
#   'that',
#   'on',
#   'will',
#   'all',
#   'for',
#   'no',
#   'have',
#   'so',
#   'but',
#   'with',
#   'when',
#   'like',
#   'now',
#   'time',
#   'there',
#   'up',
#   'one',
#   'they',
#   'down',
#   'say',
#   'would',
#   'at',
#   'away',
#   'yeah',
#   'by',
#   'need',
#   'world',
#   'caus',
#   'an',
#   'wo',
#   'still',
#   'us',
#   'littl',
#   'call',
#   'leav',
#   'them',
#   'end',
#   'hear',
#   'their',
#   'friend',
#   'realli',
#   'seem',
#   'close',
#   'while',
#   'yes',
#   'onc',
#   'today',
#   'roll',
#   'listen',
#   'sea',
#   'citi',
#   'hous',
#   'laugh',
#   'blow',
#   'carri',
#   'anymor',
#   'sign',
#   'read',
#   'point',
#   'finger',
#   'comin',
#   'hill',
#   'quiet',
#   'rich',
#   'stood',
#   'bill',
#   'card',
#   'store',
#   'settl',
#   'sayin',
#   'admit',
#   'pink',
#   'sweep',
#   'repent',
#   'proof',
#   'factori',
#   'credit',
#   'villag'],
#  'TRAAAUC128F428716F': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'are',
#   'we',
#   'all',
#   'be',
#   'have',
#   'love',
#   'when',
#   'time',
#   'can',
#   'there',
#   'up',
#   'heart',
#   'where',
#   'tell',
#   'live',
#   'wo',
#   'then',
#   'light',
#   'call',
#   'home',
#   'hear',
#   'place',
#   'much',
#   'left',
#   'new',
#   'than',
#   'chorus',
#   'own',
#   'mine',
#   'tear',
#   'use',
#   'rememb',
#   'kiss',
#   'open',
#   'mayb',
#   'broken',
#   'fade',
#   'nobodi',
#   'memori',
#   'hous',
#   'somebodi',
#   'meet',
#   'apart',
#   'sinc',
#   'afraid',
#   'window',
#   'piec',
#   'drown',
#   'everyday',
#   'wine',
#   'dove',
#   'sweeter'],
#  'TRAAAZF12903CCCF6B': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'your',
#   'that',
#   'on',
#   'are',
#   'am',
#   'will',
#   'have',
#   'so',
#   'but',
#   'what',
#   'like',
#   'now',
#   'down',
#   'get',
#   'she',
#   'was',
#   'see',
#   'if',
#   'got',
#   'never',
#   'feel',
#   'want',
#   'let',
#   'say',
#   'at',
#   'away',
#   'her',
#   'night',
#   'look',
#   'gonna',
#   'tell',
#   'whi',
#   'keep',
#   'dream',
#   'wo',
#   'girl',
#   'find',
#   'over',
#   'littl',
#   'said',
#   'did',
#   'had',
#   'hold',
#   'run',
#   'ya',
#   'last',
#   'anoth',
#   'break',
#   'move',
#   'mean',
#   'doe',
#   'work',
#   'touch',
#   'behind',
#   'ai',
#   'under',
#   'ground',
#   'road',
#   'reason',
#   'nobodi',
#   'past',
#   'meet',
#   'pray',
#   'slow',
#   'fast',
#   'nothin',
#   'clean',
#   'sail',
#   'drag',
#   'runnin',
#   'noon',
#   'boat',
#   'movin',
#   'row',
#   'china',
#   'wilder',
#   'rocki',
#   'stride'],
#  'TRAABEV12903CC53A4': ['the',
#   'to',
#   'a',
#   'in',
#   'your',
#   'on',
#   'time',
#   'caus',
#   'face',
#   'head',
#   'place',
#   'pain',
#   'wrong',
#   'dead',
#   'real',
#   'fear',
#   'blood',
#   'gun',
#   'scare',
#   'disgrac'],
#  'TRAABHB12903CAFC2F': ['i',
#   'the',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'in',
#   'is',
#   'of',
#   'that',
#   'do',
#   'on',
#   'am',
#   'all',
#   'for',
#   'love',
#   'so',
#   'what',
#   'now',
#   'time',
#   'go',
#   'they',
#   'was',
#   'from',
#   'he',
#   'take',
#   'away',
#   'by',
#   'our',
#   'look',
#   'an',
#   'his',
#   'some',
#   'littl',
#   'then',
#   'had',
#   'face',
#   'alon',
#   'god',
#   'left',
#   'him',
#   'made',
#   'far',
#   'rain',
#   'rememb',
#   'line',
#   'onc',
#   'until',
#   'saw',
#   'soon',
#   'feet',
#   'empti',
#   'stone',
#   'cool',
#   'ten',
#   'mirror',
#   'spread',
#   'crime',
#   'vain',
#   'view',
#   'proud',
#   'sent',
#   'draw',
#   'mass',
#   'horizon',
#   'becam',
#   'silli',
#   'claw',
#   'coin',
#   'product',
#   'idol',
#   'poet',
#   'plea',
#   'dreamt',
#   'subject',
#   'lili'],
#  'TRAABHC128F933A3F8': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'for',
#   'be',
#   'know',
#   'with',
#   'just',
#   'like',
#   'time',
#   'go',
#   'up',
#   'oh',
#   'they',
#   'out',
#   'down',
#   'want',
#   'make',
#   'as',
#   'day',
#   'away',
#   'here',
#   'night',
#   'our',
#   'where',
#   'eye',
#   'right',
#   'through',
#   'too',
#   'well',
#   'find',
#   'fall',
#   'around',
#   'littl',
#   'wait',
#   'hold',
#   'run',
#   'them',
#   'stay',
#   'anoth',
#   'sun',
#   'off',
#   'sky',
#   'hope',
#   'watch',
#   'same',
#   'own',
#   'other',
#   'forev',
#   'close',
#   'kiss',
#   'two',
#   'open',
#   'il',
#   'side',
#   'fli',
#   'found',
#   'onc',
#   'togeth',
#   'shine',
#   'mani',
#   'morn',
#   'sit',
#   'fade',
#   'follow',
#   'wake',
#   'blind',
#   'each',
#   'reach',
#   'soon',
#   'abov',
#   'tree',
#   'differ',
#   'summer',
#   'outsid',
#   'cos',
#   'spend',
#   'slowli',
#   'besid',
#   'remind',
#   'below',
#   'wrap',
#   'weather',
#   'seed',
#   'underneath',
#   'breez',
#   'wherev',
#   'creep',
#   'w',
#   'pink',
#   'collid',
#   'mate',
#   'grain',
#   'pine',
#   'branch'],
#  'TRAABIG128F9356C56': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'am',
#   'all',
#   'for',
#   'no',
#   'have',
#   'love',
#   'so',
#   'know',
#   'this',
#   'but',
#   'what',
#   'when',
#   'like',
#   'now',
#   'time',
#   'can',
#   'there',
#   'up',
#   'oh',
#   'they',
#   'out',
#   'down',
#   'get',
#   'she',
#   'was',
#   'if',
#   'got',
#   'never',
#   'he',
#   'feel',
#   'make',
#   'say',
#   'take',
#   'would',
#   'as',
#   'babi',
#   'life',
#   'yeah',
#   'back',
#   'by',
#   'her',
#   'heart',
#   'look',
#   'eye',
#   'world',
#   'die',
#   'think',
#   'live',
#   'give',
#   'or',
#   'dream',
#   'an',
#   'his',
#   'girl',
#   'wanna',
#   'find',
#   'about',
#   'over',
#   'littl',
#   'then',
#   'noth',
#   'everi',
#   'did',
#   'had',
#   'walk',
#   'ever',
#   'hear',
#   'cri',
#   'hey',
#   'place',
#   'stand',
#   'anoth',
#   'play',
#   'thought',
#   'sing',
#   'start',
#   'realli',
#   'da',
#   'even',
#   'pleas',
#   'watch',
#   'gotta',
#   'talk',
#   'own',
#   'bring',
#   'someon',
#   'high',
#   'doe',
#   'year',
#   'fli',
#   'black',
#   'lose',
#   'wonder',
#   'help',
#   'work',
#   'street',
#   'hide',
#   'everybodi',
#   'town',
#   'listen',
#   'first',
#   'beat',
#   'goodby',
#   'wall',
#   'sit',
#   'scream',
#   'sad',
#   'laugh',
#   'went',
#   'meet',
#   'hang',
#   'mother',
#   'speak',
#   'stori',
#   'cannot',
#   'window',
#   'dear',
#   'outsid',
#   'across',
#   'caught',
#   'father',
#   'win',
#   'sens',
#   'space',
#   'drown',
#   'scare',
#   'daddi',
#   'dont',
#   'pa',
#   'ten',
#   'knock',
#   'silent',
#   'soft',
#   'shout',
#   'ba',
#   'five',
#   'silver',
#   'livin',
#   'float',
#   'figur',
#   'spent',
#   'drum',
#   'sudden',
#   'echo',
#   'attack',
#   'idea',
#   'clock',
#   'daughter',
#   'joke',
#   'wipe',
#   'screen',
#   'tick',
#   'spoke',
#   '10',
#   'screw',
#   'measur',
#   'pitch'],
#  'TRAABJS128F9325C99': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'me',
#   'that',
#   'will',
#   'for',
#   'be',
#   'so',
#   'what',
#   'when',
#   'come',
#   'there',
#   'one',
#   'she',
#   'want',
#   'way',
#   'say',
#   'by',
#   'her',
#   'eye',
#   'tell',
#   'still',
#   'turn',
#   'light',
#   'wait',
#   'hold',
#   'hard',
#   'wrong',
#   'free',
#   'fire',
#   'line',
#   'onc',
#   'save',
#   'sea',
#   'saw',
#   'white',
#   'bone',
#   'warm',
#   'gold',
#   'write',
#   'letter',
#   'stood',
#   'page',
#   'sacrific',
#   'tale',
#   'heartbreak',
#   'fairi'],
#  'TRAABJV128F1460C49': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'my',
#   'is',
#   'do',
#   'on',
#   'we',
#   'am',
#   'will',
#   'all',
#   'no',
#   'be',
#   'have',
#   'love',
#   'so',
#   'but',
#   'just',
#   'time',
#   'can',
#   'come',
#   'oh',
#   'out',
#   'down',
#   'see',
#   'if',
#   'feel',
#   'want',
#   'let',
#   'make',
#   'say',
#   'take',
#   'babi',
#   'heart',
#   'here',
#   'our',
#   'where',
#   'caus',
#   'gonna',
#   'been',
#   'tell',
#   'think',
#   'again',
#   'keep',
#   'well',
#   'us',
#   'long',
#   'girl',
#   'wanna',
#   'about',
#   'littl',
#   'ya',
#   'has',
#   'soul',
#   'tonight',
#   'play',
#   'break',
#   'move',
#   'fire',
#   'use',
#   'real',
#   'sound',
#   'ride',
#   'till',
#   'town',
#   'set',
#   'alright',
#   'game',
#   'anyth',
#   'strong',
#   'great',
#   'honey',
#   'cool',
#   'darl',
#   'mad',
#   'rule',
#   'desir',
#   'midnight',
#   'highway',
#   'celebr'],
#  'TRAABLR128F423B7E3': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'do',
#   'on',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'be',
#   'love',
#   'so',
#   'know',
#   'but',
#   'with',
#   'just',
#   'like',
#   'now',
#   'go',
#   'feel',
#   'at',
#   'life',
#   'by',
#   'night',
#   'need',
#   'right',
#   'tell',
#   'live',
#   'give',
#   'or',
#   'keep',
#   'well',
#   'still',
#   'us',
#   'fall',
#   'everi',
#   'leav',
#   'their',
#   'these',
#   'lost',
#   'hard',
#   'song',
#   'free',
#   'same',
#   'blue',
#   'own',
#   'tear',
#   'use',
#   'mean',
#   'line',
#   'came',
#   'ask',
#   'forget',
#   'best',
#   'hurt',
#   'music',
#   'late',
#   'wall',
#   'lead',
#   'drink',
#   'fast',
#   'tast',
#   'throw',
#   'goin',
#   'both',
#   'share',
#   'strang',
#   'yea',
#   'sink',
#   'remind',
#   'float',
#   'written',
#   'swim',
#   'brown',
#   'colour',
#   'gift',
#   'stain',
#   'refus',
#   'cigarett',
#   'convers',
#   'vocal',
#   'possibl',
#   'complain',
#   'collect',
#   'pool',
#   'product',
#   'william',
#   'produc',
#   'french',
#   'insist'],
#  'TRAABOA128F933684A': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'do',
#   'on',
#   'are',
#   'we',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'love',
#   'so',
#   'this',
#   'with',
#   'can',
#   'come',
#   'there',
#   'up',
#   'one',
#   'they',
#   'see',
#   'got',
#   'from',
#   'he',
#   'say',
#   'take',
#   'ca',
#   'away',
#   'life',
#   'yeah',
#   'heart',
#   'our',
#   'look',
#   'thing',
#   'whi',
#   'his',
#   'call',
#   'much',
#   'better',
#   'sing',
#   'peopl',
#   'song',
#   'hope',
#   'free',
#   'togeth',
#   'help',
#   'work',
#   'set',
#   'earth',
#   'somebodi',
#   'pray',
#   'king',
#   'answer',
#   'brother',
#   'father',
#   'dem',
#   'question',
#   'sister',
#   'prais',
#   'queen',
#   'book',
#   'prayer',
#   'special',
#   'thunder',
#   'youth',
#   'b',
#   'stole',
#   'jah',
#   'lightn',
#   'creation',
#   'treasur',
#   'common',
#   'lion',
#   'goal',
#   'sucker',
#   'equal',
#   'shook',
#   'achiev',
#   'background',
#   'almighti',
#   'gutter',
#   'captiv',
#   'pollut',
#   'majesti',
#   'uniti',
#   'assur'],
#  'TRAABOG128F42955B1': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'that',
#   'do',
#   'on',
#   'am',
#   'will',
#   'be',
#   'so',
#   'this',
#   'with',
#   'just',
#   'can',
#   'up',
#   'one',
#   'they',
#   'down',
#   'get',
#   'was',
#   'got',
#   'feel',
#   'want',
#   'say',
#   'day',
#   'at',
#   'babi',
#   'life',
#   'how',
#   'world',
#   'more',
#   'right',
#   'through',
#   'give',
#   'wanna',
#   'around',
#   'some',
#   'over',
#   'walk',
#   'much',
#   'god',
#   'soul',
#   'new',
#   'burn',
#   'break',
#   'start',
#   'hard',
#   'gotta',
#   'line',
#   'door',
#   'today',
#   'street',
#   'follow',
#   'citi',
#   'sad',
#   'cut',
#   'silenc',
#   'tast',
#   'bone',
#   'tight',
#   'million',
#   'shot',
#   'stranger',
#   'few',
#   'brand',
#   'wrap',
#   'march',
#   'york',
#   'grown',
#   'saint',
#   'loneli',
#   'concret',
#   'stair',
#   'standin',
#   'holdin',
#   'avenu',
#   'parasit',
#   'spanish',
#   'rome',
#   'ember'],
#  'TRAABPG128F14774DD': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'love',
#   'so',
#   'this',
#   'with',
#   'what',
#   'just',
#   'come',
#   'go',
#   'up',
#   'one',
#   'out',
#   'get',
#   'see',
#   'if',
#   'got',
#   'never',
#   'want',
#   'make',
#   'heart',
#   'look',
#   'who',
#   'through',
#   'whi',
#   'fall',
#   'lie',
#   'face',
#   'their',
#   'word',
#   'better',
#   'soul',
#   'than',
#   'play',
#   'care',
#   'name',
#   'talk',
#   'someon',
#   'sweet',
#   'kiss',
#   'smile',
#   'done',
#   'ooh',
#   'wonder',
#   'enough',
#   'work',
#   'everybodi',
#   'sometim',
#   'easi',
#   'game',
#   'along',
#   'crazi',
#   'hit',
#   'everyon',
#   'fun',
#   'perfect',
#   'secret',
#   'catch',
#   'shame',
#   'cos',
#   'tie',
#   'higher',
#   'paint',
#   'stranger',
#   'tongu',
#   'funni',
#   'sex',
#   'quick',
#   'fix',
#   'expect',
#   'gentl',
#   'further'],
#  'TRAABVM128F92CA9DC': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'love',
#   'so',
#   'know',
#   'this',
#   'with',
#   'what',
#   'just',
#   'like',
#   'now',
#   'can',
#   'come',
#   'up',
#   'one',
#   'down',
#   'get',
#   'was',
#   'if',
#   'from',
#   'make',
#   'way',
#   'take',
#   'as',
#   'day',
#   'away',
#   'life',
#   'here',
#   'how',
#   'eye',
#   'thing',
#   'world',
#   'gonna',
#   'die',
#   'right',
#   'tell',
#   'who',
#   'through',
#   'live',
#   'keep',
#   'dream',
#   'well',
#   'everi',
#   'face',
#   'everyth',
#   'chang',
#   'god',
#   'these',
#   'anoth',
#   'sun',
#   'thought',
#   'peopl',
#   'without',
#   'pain',
#   'seem',
#   'true',
#   'close',
#   'kiss',
#   'wish',
#   'done',
#   'mayb',
#   'heaven',
#   'big',
#   'everybodi',
#   'happi',
#   'ai',
#   'hurt',
#   'alright',
#   'sea',
#   'under',
#   'reason',
#   'aliv',
#   'earth',
#   'abov',
#   'whole',
#   'mother',
#   'cannot',
#   'brother',
#   'share',
#   'caught',
#   'father',
#   'brain',
#   'someday',
#   'color',
#   'race',
#   'feelin',
#   'sister',
#   'imagin',
#   'sent',
#   'fantasi',
#   'among',
#   'creatur',
#   'simpli',
#   'imposs',
#   'givin',
#   'harmoni',
#   'everlast',
#   'daydream'],
#  'TRAABXH128F42955D6': ['i',
#   'the',
#   'you',
#   'and',
#   'a',
#   'it',
#   'in',
#   'my',
#   'your',
#   'on',
#   'we',
#   'am',
#   'will',
#   'be',
#   'so',
#   'this',
#   'can',
#   'say',
#   'as',
#   'at',
#   'could',
#   'look',
#   'eye',
#   'thing',
#   'through',
#   'keep',
#   'an',
#   'still',
#   'find',
#   'said',
#   'wait',
#   'them',
#   'hear',
#   'word',
#   'last',
#   'far',
#   'tear',
#   'those',
#   'year',
#   'music',
#   'goodby',
#   'though',
#   'soon',
#   'apart',
#   'summer',
#   'futur',
#   'most',
#   'letter',
#   'screen',
#   'date',
#   'sincer',
#   'septemb'],
#  'TRAACER128F4290F96': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'of',
#   'your',
#   'do',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'be',
#   'have',
#   'so',
#   'know',
#   'this',
#   'but',
#   'just',
#   'like',
#   'can',
#   'come',
#   'there',
#   'go',
#   'up',
#   'they',
#   'down',
#   'see',
#   'never',
#   'feel',
#   'let',
#   'say',
#   'take',
#   'babi',
#   'yeah',
#   'back',
#   'heart',
#   'could',
#   'night',
#   'look',
#   'where',
#   'eye',
#   'world',
#   'caus',
#   'gonna',
#   'right',
#   'think',
#   'well',
#   'wo',
#   'long',
#   'wanna',
#   'find',
#   'over',
#   'noth',
#   'everi',
#   'into',
#   'leav',
#   'home',
#   'ever',
#   'them',
#   'face',
#   'head',
#   'befor',
#   'place',
#   'much',
#   'last',
#   'anoth',
#   'tonight',
#   'off',
#   'show',
#   'break',
#   'start',
#   'sky',
#   'wrong',
#   'danc',
#   'dead',
#   'bring',
#   'close',
#   'fight',
#   'star',
#   'kill',
#   'high',
#   'ooh',
#   'ride',
#   'street',
#   'bodi',
#   'told',
#   'first',
#   'beat',
#   'broken',
#   'game',
#   'fine',
#   'soon',
#   'rest',
#   'empti',
#   'pretti',
#   'tire',
#   'til',
#   'felt',
#   'push',
#   'drop',
#   'bout',
#   'bone',
#   'both',
#   'shut',
#   'stranger',
#   'note',
#   'candi',
#   'corps',
#   'ought',
#   'alley',
#   'blanket',
#   'ambit',
#   'gown'],
#  'TRAACFV128F935E50B': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'in',
#   'my',
#   'of',
#   'your',
#   'that',
#   'we',
#   'am',
#   'will',
#   'be',
#   'have',
#   'so',
#   'but',
#   'just',
#   'when',
#   'now',
#   'they',
#   'down',
#   'she',
#   'see',
#   'he',
#   'feel',
#   'want',
#   'would',
#   'as',
#   'babi',
#   'by',
#   'her',
#   'thing',
#   'think',
#   'littl',
#   'said',
#   'hold',
#   'word',
#   'tonight',
#   'show',
#   'must',
#   'kiss',
#   'hate',
#   'arm',
#   'morn',
#   'em',
#   'music',
#   'fade',
#   'readi',
#   'crazi',
#   'such',
#   'laugh',
#   'went',
#   'bed',
#   'ring',
#   'mama',
#   'lip',
#   'both',
#   'daddi',
#   'd',
#   'poor',
#   'complet',
#   'diamond',
#   'pack',
#   'john',
#   'sayin',
#   'posit',
#   'steadi',
#   'wed',
#   'flip',
#   'jame',
#   'peak',
#   'faint',
#   'ladder',
#   'husband'],
#  'TRAACHN128F1489601': ['i',
#   'the',
#   'you',
#   'and',
#   'a',
#   'it',
#   'not',
#   'is',
#   'of',
#   'your',
#   'on',
#   'we',
#   'am',
#   'be',
#   'have',
#   'so',
#   'this',
#   'with',
#   'just',
#   'like',
#   'time',
#   'one',
#   'never',
#   'from',
#   'say',
#   'life',
#   'back',
#   'could',
#   'look',
#   'where',
#   'world',
#   'been',
#   'again',
#   'onli',
#   'wo',
#   'were',
#   'end',
#   'last',
#   'stop',
#   'off',
#   'peopl',
#   'made',
#   'start',
#   'should',
#   'far',
#   'yes',
#   'wish',
#   'onc',
#   'might',
#   'round',
#   'road',
#   'trust',
#   'send',
#   'brain',
#   'exist',
#   'track',
#   'problem',
#   'band',
#   'singl',
#   'messag',
#   'bend',
#   'ran',
#   'illus',
#   'x4',
#   'list',
#   'wrist',
#   'vibe',
#   'solv',
#   'conclus'],
#  'TRAACIE128F428495B': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'are',
#   'all',
#   'for',
#   'no',
#   'love',
#   'so',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'like',
#   'can',
#   'come',
#   'there',
#   'up',
#   'one',
#   'was',
#   'if',
#   'never',
#   'from',
#   'let',
#   'say',
#   'ca',
#   'yeah',
#   'by',
#   'who',
#   'too',
#   'well',
#   'his',
#   'some',
#   'over',
#   'said',
#   'head',
#   'someth',
#   'much',
#   'these',
#   'better',
#   'off',
#   'start',
#   'song',
#   'talk',
#   'true',
#   'fuck',
#   'two',
#   'done',
#   'today',
#   'hate',
#   'truth',
#   'ani',
#   'dan',
#   'sit',
#   'room',
#   's',
#   'whole',
#   't',
#   'power',
#   'bleed',
#   'brother',
#   '2',
#   'belong',
#   'damn',
#   'rule',
#   'finger',
#   'storm',
#   '1',
#   'vers',
#   'escap',
#   'famili',
#   'broke',
#   'small',
#   'bridg',
#   'stick',
#   'don',
#   'dare',
#   'pure',
#   'pop',
#   'drum',
#   'youth',
#   'certain',
#   'tabl',
#   'j',
#   'hook',
#   'motherfuck',
#   'enjoy',
#   'clown',
#   'except',
#   'bass',
#   'joe',
#   'sacr',
#   'common',
#   'p',
#   'violent',
#   'jam',
#   'pearl',
#   'jealous',
#   'mike',
#   'dedic',
#   'tore',
#   'outro',
#   'bunch',
#   'symbol'],
#  'TRAACIR128F42963AC': ['the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'so',
#   'this',
#   'but',
#   'with',
#   'just',
#   'time',
#   'there',
#   'go',
#   'up',
#   'down',
#   'was',
#   'never',
#   'he',
#   'let',
#   'as',
#   'at',
#   'away',
#   'life',
#   'by',
#   'look',
#   'eye',
#   'been',
#   'through',
#   'give',
#   'keep',
#   'dream',
#   'us',
#   'his',
#   'fall',
#   'good',
#   'hand',
#   'hold',
#   'walk',
#   'head',
#   'word',
#   'god',
#   'better',
#   'stop',
#   'thought',
#   'boy',
#   'watch',
#   'pain',
#   'same',
#   'forev',
#   'sleep',
#   'must',
#   'star',
#   'fli',
#   'shine',
#   'today',
#   'may',
#   'ground',
#   'grow',
#   'anyth',
#   'young',
#   'moon',
#   'such',
#   'earth',
#   'next',
#   'felt',
#   'thank',
#   'evil',
#   'brain',
#   'space',
#   'count',
#   'etern',
#   'realiz',
#   'mistak',
#   'suffer',
#   'tie',
#   'clean',
#   'okay',
#   'strength',
#   'ship',
#   'fix',
#   'asleep',
#   'weather',
#   'underneath',
#   'box',
#   'boot',
#   'armi',
#   'scratch',
#   'flag',
#   'bay',
#   'sheep',
#   'captain',
#   'pile',
#   'prize',
#   'cancer',
#   'stormi',
#   'correct',
#   'chin',
#   'admir',
#   '100'],
#  'TRAACJC128F934ABB5': ['i',
#   'the',
#   'you',
#   'to',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'do',
#   'are',
#   'will',
#   'no',
#   'be',
#   'have',
#   'know',
#   'with',
#   'just',
#   'when',
#   'now',
#   'time',
#   'never',
#   'from',
#   'let',
#   'make',
#   'say',
#   'as',
#   'by',
#   'look',
#   'eye',
#   'thing',
#   'been',
#   'tell',
#   'or',
#   'dream',
#   'mind',
#   'hand',
#   'noth',
#   'everi',
#   'into',
#   'hear',
#   'everyth',
#   'word',
#   'stay',
#   'friend',
#   'even',
#   'watch',
#   'same',
#   'close',
#   'rememb',
#   'ask',
#   'till',
#   'forget',
#   'els',
#   'wake',
#   'anyth',
#   'though',
#   'control',
#   'veri',
#   'power',
#   'sinc',
#   'becom',
#   'afraid',
#   'which',
#   'brain',
#   'finger',
#   'escap',
#   'hello',
#   'realiti',
#   'emot',
#   'comfort',
#   'forgotten',
#   'speed',
#   'asleep',
#   'direct',
#   'fantasi',
#   'reveal',
#   'hidden',
#   'seat',
#   'relax',
#   'heartbeat',
#   'awaken',
#   'reaction',
#   'experi',
#   'movement',
#   'hypnot',
#   'snap',
#   'distract',
#   'sleepi',
#   'spiral',
#   'tranc',
#   'effort'],
#  'TRAACPH12903CF5F14': ['the',
#   'you',
#   'and',
#   'a',
#   'in',
#   'is',
#   'your',
#   'we',
#   'will',
#   'no',
#   'so',
#   'this',
#   'with',
#   'when',
#   'come',
#   'they',
#   'see',
#   'as',
#   'our',
#   'eye',
#   'thing',
#   'live',
#   'everyth',
#   'word',
#   'much',
#   'last',
#   'play',
#   'sing',
#   'seem',
#   'dark',
#   'forev',
#   'close',
#   'mean',
#   'fade',
#   'rest',
#   'cannot',
#   'summer',
#   'winter',
#   'longer',
#   'surviv',
#   'doubl',
#   'bath',
#   'featur'],
#  'TRAACQW128F428854F': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'are',
#   'will',
#   'all',
#   'be',
#   'have',
#   'love',
#   'so',
#   'but',
#   'what',
#   'when',
#   'can',
#   'up',
#   'one',
#   'see',
#   'got',
#   'feel',
#   'make',
#   'way',
#   'take',
#   'as',
#   'day',
#   'back',
#   'heart',
#   'how',
#   'tri',
#   'well',
#   'everyth',
#   'stay',
#   'place',
#   'sing',
#   'break',
#   'sky',
#   'song',
#   'move',
#   'fire',
#   'star',
#   'cold',
#   'becaus',
#   'might',
#   'rise',
#   'though',
#   'past',
#   'memori',
#   'rest',
#   'child',
#   'peac',
#   'tire',
#   'near',
#   'piec',
#   'someday',
#   'wide',
#   'movi',
#   'trick'],
#  'TRAACRY12903CAF2C2': ['a',
#   'me',
#   'no',
#   'que',
#   'de',
#   'la',
#   'y',
#   'en',
#   'un',
#   'el',
#   'te',
#   'tu',
#   'se',
#   'mi',
#   'ya',
#   'si',
#   'por',
#   'lo',
#   'con',
#   'una',
#   'al',
#   'como',
#   'los',
#   'ha',
#   'air',
#   'mas',
#   'pero',
#   'nada',
#   'voy',
#   'tus',
#   'mis',
#   'nunca',
#   'sur',
#   'estoy',
#   'tanto',
#   'van',
#   'dia',
#   'entr',
#   'otra',
#   'hace',
#   'algo',
#   'luna',
#   'vece',
#   'recuerdo',
#   'sola',
#   'viento',
#   'ves',
#   'mismo',
#   'estrella',
#   'fuera',
#   'pelo',
#   'ze',
#   'hacia',
#   'bueno',
#   'deseo',
#   'llena',
#   'especi',
#   'piensa',
#   'hizo',
#   'nube',
#   'pierdo',
#   'espejo',
#   'dedo',
#   'magia'],
#  'TRAACUP128E0789C69': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'that',
#   'do',
#   'on',
#   'am',
#   'no',
#   'so',
#   'this',
#   'just',
#   'time',
#   'there',
#   'go',
#   'down',
#   'get',
#   'got',
#   'let',
#   'way',
#   'at',
#   'back',
#   'her',
#   'need',
#   'more',
#   'caus',
#   'been',
#   'tell',
#   'man',
#   'or',
#   'littl',
#   'turn',
#   'hey',
#   'much',
#   'move',
#   'sleep',
#   'line',
#   'till',
#   'ai',
#   'first',
#   'pass',
#   'learn',
#   'reach',
#   'meet',
#   'car',
#   'ladi',
#   'pick',
#   'send',
#   'fair',
#   'track',
#   'speed',
#   'paid',
#   'hurri',
#   'beer',
#   'waitin',
#   'class',
#   'station',
#   'engin',
#   'mister',
#   'chicken',
#   'third',
#   'driver',
#   'rate',
#   'railroad'],
#  'TRAACZN128F93236B1': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'on',
#   'are',
#   'am',
#   'for',
#   'be',
#   'so',
#   'but',
#   'with',
#   'like',
#   'go',
#   'up',
#   'they',
#   'was',
#   'see',
#   'never',
#   'he',
#   'feel',
#   'make',
#   'would',
#   'ca',
#   'by',
#   'need',
#   'our',
#   'look',
#   'where',
#   'who',
#   'live',
#   'tri',
#   'dream',
#   'an',
#   'some',
#   'littl',
#   'noth',
#   'everi',
#   'into',
#   'run',
#   'walk',
#   'face',
#   'head',
#   'believ',
#   'their',
#   'insid',
#   'befor',
#   'left',
#   'sun',
#   'thought',
#   'sing',
#   'realli',
#   'sky',
#   'song',
#   'watch',
#   'wrong',
#   'put',
#   'own',
#   'fuck',
#   'someon',
#   'must',
#   'kill',
#   'high',
#   'blood',
#   'behind',
#   'ride',
#   'hide',
#   'roll',
#   'lone',
#   'set',
#   'pass',
#   'under',
#   'road',
#   'rise',
#   'fill',
#   'game',
#   'water',
#   'blind',
#   'along',
#   'upon',
#   'drive',
#   'pull',
#   'peac',
#   'mother',
#   'til',
#   'kid',
#   'floor',
#   'bleed',
#   'warm',
#   'eat',
#   'pictur',
#   'nowher',
#   'space',
#   'ocean',
#   'finger',
#   'dress',
#   'lock',
#   'fate',
#   'wash',
#   'race',
#   'check',
#   'wit',
#   'wheel',
#   'prayer',
#   'besid',
#   'crash',
#   'price',
#   'guid',
#   'passion',
#   'written',
#   'shore',
#   'om',
#   'glow',
#   'bite',
#   'west',
#   'deserv',
#   'yellow',
#   'fame',
#   'chest',
#   'flag',
#   'engin',
#   'plant',
#   'sever',
#   'lane',
#   'discov',
#   'drove',
#   'chant',
#   'beam',
#   'unto',
#   'collid',
#   'purpl',
#   'immort',
#   'indian',
#   'practic',
#   'tank',
#   'gasolin',
#   'wooden',
#   'shark',
#   'clone'],
#  'TRAADAA128F92F7043': ['a',
#   'do',
#   'no',
#   'de',
#   'se',
#   'face',
#   'o',
#   'da',
#   'na',
#   'não',
#   'pra',
#   'sol',
#   'dos',
#   'dentro',
#   'luz',
#   'seu',
#   'ao',
#   'cantar',
#   'sombra',
#   'mala',
#   'quanto',
#   'são',
#   'rua',
#   'correr',
#   'nossa',
#   'lua',
#   'santo'],
#  'TRAADBN128F932D00A': ['me',
#   'que',
#   'de',
#   'la',
#   'en',
#   'un',
#   'se',
#   'le',
#   'du',
#   'je',
#   'et',
#   'les',
#   'il',
#   'qui',
#   'pass',
#   'pas',
#   'dan',
#   'mai',
#   'pour',
#   'ne',
#   'à',
#   's',
#   'rest',
#   'tout',
#   'va',
#   'bien',
#   'm',
#   'mon',
#   'au',
#   'moi',
#   'une',
#   'mal',
#   'n',
#   'sur',
#   'jai',
#   'san',
#   'quand',
#   'ou',
#   'ça',
#   'fait',
#   'l',
#   'par',
#   'march',
#   'jour',
#   'mond',
#   'brave',
#   'petit',
#   'j',
#   'fai',
#   'leur',
#   'regard',
#   'lit',
#   'terr',
#   'voir',
#   'lon',
#   'rue',
#   'autr',
#   'qu',
#   'gen',
#   'pourquoi',
#   'sonn',
#   'rout',
#   'personn',
#   'soi',
#   'villag',
#   'croi',
#   'rome',
#   'musiqu',
#   'sil',
#   'besoin',
#   'chemin',
#   'pourtant',
#   'doigt'],
#  'TRAADCQ128F93436C3': ['a',
#   'me',
#   'no',
#   'que',
#   'de',
#   'la',
#   'y',
#   'en',
#   'un',
#   'el',
#   'te',
#   'tu',
#   'se',
#   'mi',
#   'ya',
#   'yo',
#   'si',
#   'por',
#   'lo',
#   'amor',
#   'con',
#   'al',
#   'ti',
#   'para',
#   'sea',
#   'las',
#   'vida',
#   'su',
#   'ni',
#   'ser',
#   'va',
#   'más',
#   'tus',
#   'siempr',
#   'mis',
#   'nunca',
#   'tan',
#   'tiempo',
#   'tú',
#   'tanto',
#   'dond',
#   'está',
#   'corazón',
#   'era',
#   'cada',
#   'ahora',
#   'don',
#   'alma',
#   'cielo',
#   'pued',
#   'hace',
#   'vivir',
#   'sé',
#   'cruel',
#   'día',
#   'sueño',
#   'mí',
#   'aquí',
#   'hacer',
#   'voz',
#   'bis',
#   'camino',
#   'tard',
#   'pena',
#   'conmigo',
#   'fui',
#   'paso',
#   'ment',
#   'mismo',
#   'morir',
#   'destino',
#   'andar',
#   'silencio',
#   'vive',
#   'aquel',
#   'forma',
#   'volar',
#   'cuenta',
#   'negro',
#   'espera',
#   'razón',
#   'pueda',
#   'olvido',
#   'herida',
#   'cambiar',
#   'despertar',
#   'cancion',
#   'llevo',
#   'partir',
#   'doy',
#   'cuanto',
#   'sentimiento',
#   'adió',
#   'esperanza',
#   'decirt',
#   'creer',
#   'comprend',
#   'impos',
#   'secreto',
#   'quizá',
#   'eterno',
#   'pecho',
#   'iba',
#   'pude',
#   'piedra',
#   'amiga',
#   'pensamiento',
#   'escuchar',
#   'gritar',
#   'aquello'],
#  'TRAADKA12903CD2511': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'have',
#   'so',
#   'know',
#   'but',
#   'what',
#   'just',
#   'when',
#   'time',
#   'can',
#   'come',
#   'they',
#   'get',
#   'was',
#   'got',
#   'never',
#   'want',
#   'say',
#   'as',
#   'at',
#   'how',
#   'look',
#   'thing',
#   'tell',
#   'think',
#   'through',
#   'too',
#   'onli',
#   'tri',
#   'long',
#   'wanna',
#   'over',
#   'turn',
#   'noth',
#   'did',
#   'wait',
#   'home',
#   'hold',
#   'ever',
#   'believ',
#   'everyth',
#   'stay',
#   'much',
#   'stand',
#   'left',
#   'him',
#   'should',
#   'realli',
#   'hard',
#   'even',
#   'care',
#   'hope',
#   'free',
#   'blue',
#   'own',
#   'breath',
#   'door',
#   'wonder',
#   'heaven',
#   'hide',
#   'save',
#   'sure',
#   'until',
#   'sea',
#   'money',
#   'heard',
#   'though',
#   'tomorrow',
#   'earth',
#   'happen',
#   'between',
#   'pay',
#   'til',
#   'cos',
#   'phone',
#   'knock',
#   'corner',
#   'ago',
#   'danger',
#   'price',
#   'passion',
#   'tune',
#   'trap',
#   'televis',
#   'tap'],
#  'TRAADKW128E079503A': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'we',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'when',
#   'like',
#   'can',
#   'go',
#   'out',
#   'get',
#   'she',
#   'was',
#   'see',
#   'got',
#   'from',
#   'he',
#   'feel',
#   'want',
#   'make',
#   'way',
#   'say',
#   'take',
#   'would',
#   'as',
#   'at',
#   'away',
#   'life',
#   'here',
#   'could',
#   'our',
#   'look',
#   'thing',
#   'more',
#   'die',
#   'been',
#   'man',
#   'live',
#   'give',
#   'too',
#   'or',
#   'keep',
#   'wo',
#   'still',
#   'us',
#   'his',
#   'girl',
#   'find',
#   'littl',
#   'noth',
#   'light',
#   'said',
#   'alway',
#   'were',
#   'did',
#   'into',
#   'leav',
#   'had',
#   'someth',
#   'befor',
#   'stay',
#   'place',
#   'better',
#   'friend',
#   'left',
#   'him',
#   'than',
#   'tonight',
#   'off',
#   'thought',
#   'start',
#   'old',
#   'care',
#   'hope',
#   'move',
#   'gotta',
#   'far',
#   'someon',
#   'myself',
#   'mean',
#   'rememb',
#   'fli',
#   'lose',
#   'enough',
#   'togeth',
#   'mayb',
#   'work',
#   'save',
#   'arm',
#   'bodi',
#   'ai',
#   'round',
#   'late',
#   'ani',
#   'money',
#   'citi',
#   'young',
#   'lay',
#   'hous',
#   'somebodi',
#   'went',
#   'drive',
#   'car',
#   'drink',
#   'pay',
#   'kid',
#   'fast',
#   'cross',
#   'felt',
#   'mama',
#   'plan',
#   'somewher',
#   'both',
#   'belong',
#   'nowher',
#   'bit',
#   'quit',
#   'nice',
#   'buy',
#   'bar',
#   'problem',
#   'school',
#   'deal',
#   'prove',
#   'job',
#   'shoulder',
#   'wrap',
#   'bottl',
#   'ourselv',
#   'speed',
#   'drunk',
#   'anywher',
#   'bill',
#   'store',
#   'shelter',
#   'bigger',
#   'decis',
#   'ticket',
#   'zero',
#   'border',
#   'entertain',
#   'cruis',
#   'manag',
#   'market'],
#  'TRAADKZ128F149BDFF': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'not',
#   'in',
#   'my',
#   'is',
#   'do',
#   'on',
#   'we',
#   'be',
#   'have',
#   'love',
#   'know',
#   'this',
#   'with',
#   'what',
#   'when',
#   'like',
#   'now',
#   'come',
#   'there',
#   'go',
#   'one',
#   'get',
#   'was',
#   'see',
#   'got',
#   'would',
#   'at',
#   'yeah',
#   'by',
#   'her',
#   'where',
#   'more',
#   'been',
#   'an',
#   'good',
#   'hand',
#   'call',
#   'did',
#   'home',
#   'had',
#   'ever',
#   'end',
#   'ya',
#   'their',
#   'friend',
#   'left',
#   'play',
#   'chorus',
#   'fire',
#   'use',
#   'high',
#   'two',
#   'year',
#   'big',
#   'till',
#   'best',
#   'hell',
#   'hurt',
#   'nobodi',
#   'game',
#   'moon',
#   'hit',
#   'somebodi',
#   'drive',
#   'car',
#   'mother',
#   'great',
#   'perfect',
#   'bright',
#   'window',
#   'return',
#   'meant',
#   'nothin',
#   'destroy',
#   'shoot',
#   'school',
#   'ahead',
#   'few',
#   'brought',
#   'surpris',
#   'seek',
#   'bomb',
#   'outta',
#   'shape',
#   'ahh',
#   'electr',
#   'chest',
#   'dad',
#   'afternoon',
#   'grant',
#   'ol',
#   'lane',
#   'hangin',
#   'pant',
#   'base',
#   'bein',
#   'lower',
#   'shinin',
#   'sport',
#   'clutch',
#   'galaxi',
#   'ditch'],
#  'TRAADLH12903CA70EE': ['the',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'is',
#   'that',
#   'have',
#   'so',
#   'when',
#   'time',
#   'how',
#   'our',
#   'world',
#   'or',
#   'still',
#   'about',
#   'over',
#   'head',
#   'burn',
#   'care',
#   'seem',
#   'cold',
#   'mani',
#   'war',
#   'everyon',
#   'hang',
#   'sinc',
#   'rule',
#   'famili',
#   'ignor',
#   'rage',
#   'forgotten',
#   'diseas',
#   'clue',
#   'alarm',
#   'threat',
#   'nuclear'],
#  'TRAADNA128F9331246': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'not',
#   'in',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'we',
#   'am',
#   'for',
#   'no',
#   'be',
#   'just',
#   'time',
#   'come',
#   'there',
#   'oh',
#   'one',
#   'see',
#   'got',
#   'never',
#   'ca',
#   'day',
#   'by',
#   'here',
#   'night',
#   'need',
#   'eye',
#   'an',
#   'wo',
#   'some',
#   'turn',
#   'noth',
#   'light',
#   'soul',
#   'free',
#   'other',
#   'lose',
#   'help',
#   'save',
#   'after',
#   'fool',
#   'kind',
#   'money',
#   'nobodi',
#   'blind',
#   'strong',
#   'somebodi',
#   'happen',
#   'lead',
#   'trust',
#   'tight',
#   'caught',
#   'rule',
#   'weak',
#   'whatev',
#   'sell',
#   'golden',
#   'dime',
#   'dollar',
#   'hurri',
#   'rescu',
#   'cheek',
#   'ray',
#   'bop',
#   'spare',
#   'sympathi',
#   'neon',
#   'strand',
#   'hustl',
#   'tooth',
#   'beggin'],
#  'TRAADNL128F14519DF': ['i',
#   'the',
#   'you',
#   'to',
#   'me',
#   'it',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'are',
#   'am',
#   'will',
#   'for',
#   'be',
#   'love',
#   'know',
#   'with',
#   'when',
#   'come',
#   'oh',
#   'one',
#   'get',
#   'make',
#   'day',
#   'back',
#   'here',
#   'world',
#   'more',
#   'too',
#   'whi',
#   'keep',
#   'good',
#   'turn',
#   'light',
#   'into',
#   'stay',
#   'sun',
#   'true',
#   'two',
#   'enough',
#   'heaven',
#   'reason',
#   'aliv',
#   'water',
#   'great',
#   'cannot',
#   'three',
#   '&',
#   'chain',
#   'four',
#   'wine',
#   'five',
#   'seven',
#   'six',
#   'fix',
#   'nine',
#   'nah',
#   'addict',
#   'eight',
#   'meno'],
#  'TRAADNN128F42B1D94': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'not',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'be',
#   'have',
#   'know',
#   'this',
#   'but',
#   'when',
#   'like',
#   'time',
#   'up',
#   'one',
#   'she',
#   'was',
#   'if',
#   'from',
#   'make',
#   'take',
#   'would',
#   'as',
#   'babi',
#   'by',
#   'could',
#   'night',
#   'our',
#   'where',
#   'more',
#   'who',
#   'through',
#   'onli',
#   'or',
#   'over',
#   'then',
#   'call',
#   'everi',
#   'home',
#   'stay',
#   'these',
#   'better',
#   'play',
#   'should',
#   'dead',
#   'sleep',
#   'those',
#   'kill',
#   'breath',
#   'lord',
#   'onc',
#   'mayb',
#   'arm',
#   'morn',
#   'wall',
#   'matter',
#   'fill',
#   'follow',
#   'wake',
#   'aliv',
#   'lay',
#   'room',
#   'tomorrow',
#   'laugh',
#   'child',
#   'mother',
#   'lot',
#   'summer',
#   'worri',
#   'bit',
#   'finger',
#   'exist',
#   'held',
#   'bottl',
#   'victim',
#   'toe',
#   'guarante',
#   'inch',
#   'rearrang',
#   'retir'],
#  'TRAADQL128F427D281': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'on',
#   'are',
#   'am',
#   'will',
#   'all',
#   'have',
#   'love',
#   'so',
#   'know',
#   'with',
#   'when',
#   'like',
#   'time',
#   'can',
#   'go',
#   'out',
#   'down',
#   'get',
#   'she',
#   'got',
#   'from',
#   'want',
#   'make',
#   'say',
#   'take',
#   'life',
#   'back',
#   'heart',
#   'caus',
#   'gonna',
#   'die',
#   'think',
#   'tri',
#   'or',
#   'keep',
#   'wo',
#   'then',
#   'run',
#   'face',
#   'stay',
#   'better',
#   'stop',
#   'sing',
#   'name',
#   'sin',
#   'real',
#   'smile',
#   'black',
#   'blood',
#   'ride',
#   'hide',
#   'seen',
#   'hell',
#   'feet',
#   'happen',
#   'carri',
#   'gun',
#   'cross',
#   'goin',
#   'across',
#   'bone',
#   'bit',
#   'bird',
#   'shot',
#   'magic',
#   'track',
#   'stick',
#   'tongu',
#   'bare',
#   'cat',
#   'hors',
#   'weight',
#   'fat',
#   'grass',
#   'taught',
#   'suit',
#   'doubl',
#   'aim',
#   'gray',
#   'nest',
#   'freez',
#   'piss',
#   'snake',
#   'tini',
#   'pig',
#   'tragedi',
#   'thick',
#   'tail',
#   'crow',
#   'fri',
#   'sharp',
#   'vine',
#   'breast',
#   'lipstick',
#   'gotten',
#   'bean',
#   'butter',
#   'slick'],
#  'TRAADQX128F422B4CF': ['i',
#   'the',
#   'you',
#   'to',
#   'a',
#   'me',
#   'it',
#   'not',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'are',
#   'we',
#   'will',
#   'all',
#   'be',
#   'have',
#   'so',
#   'but',
#   'when',
#   'time',
#   'come',
#   'was',
#   'if',
#   'got',
#   'make',
#   'way',
#   'would',
#   'at',
#   'back',
#   'could',
#   'been',
#   'again',
#   'still',
#   'us',
#   'alway',
#   'home',
#   'ever',
#   'everyth',
#   'alon',
#   'place',
#   'friend',
#   'left',
#   'move',
#   'same',
#   'other',
#   'sin',
#   'rememb',
#   'kiss',
#   'wish',
#   'two',
#   'found',
#   'becaus',
#   'miss',
#   'forget',
#   'first',
#   'men',
#   'went',
#   'meet',
#   'mother',
#   'sinc',
#   '&',
#   'darl',
#   'read',
#   'buy',
#   'book',
#   'sore',
#   'pair',
#   'dull',
#   'twin'],
#  'TRAADSV128F42BC36A': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'your',
#   'that',
#   'do',
#   'we',
#   'will',
#   'be',
#   'have',
#   'love',
#   'so',
#   'know',
#   'this',
#   'but',
#   'just',
#   'now',
#   'time',
#   'go',
#   'get',
#   'let',
#   'way',
#   'say',
#   'would',
#   'ca',
#   'at',
#   'babi',
#   'away',
#   'heart',
#   'our',
#   'look',
#   'eye',
#   'caus',
#   'think',
#   'through',
#   'give',
#   'over',
#   'turn',
#   'then',
#   'said',
#   'alway',
#   'had',
#   'walk',
#   'stop',
#   'play',
#   'talk',
#   'mine',
#   'tear',
#   'fear',
#   'roll',
#   'fool',
#   'broken',
#   'part',
#   'game',
#   'blind',
#   'lover',
#   'lot',
#   'wear',
#   'both',
#   'dice',
#   'fals',
#   'shed',
#   'foolish',
#   'mask',
#   'masquerad'],
#  'TRAADVO128E07999E9': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'is',
#   'do',
#   'on',
#   'are',
#   'we',
#   'have',
#   'so',
#   'know',
#   'but',
#   'what',
#   'just',
#   'when',
#   'can',
#   'go',
#   'oh',
#   'one',
#   'they',
#   'down',
#   'make',
#   'as',
#   'at',
#   'away',
#   'back',
#   'our',
#   'look',
#   'world',
#   'been',
#   'tell',
#   'who',
#   'us',
#   'littl',
#   'god',
#   'last',
#   'stop',
#   'lost',
#   'without',
#   'talk',
#   'rain',
#   'star',
#   'while',
#   'mayb',
#   'wind',
#   'men',
#   'blow',
#   'king',
#   'power',
#   'sinc',
#   'blame',
#   'win',
#   'wash',
#   'simpl',
#   'toward',
#   'destin',
#   'tumbl',
#   'fragil',
#   'trial',
#   'intro',
#   'contempl'],
#  'TRAADYB128F92D7E73': ['i',
#   'the',
#   'you',
#   'and',
#   'me',
#   'it',
#   'not',
#   'my',
#   'will',
#   'for',
#   'be',
#   'love',
#   'so',
#   'know',
#   'this',
#   'with',
#   'just',
#   'can',
#   'go',
#   'one',
#   'see',
#   'feel',
#   'want',
#   'as',
#   'by',
#   'heart',
#   'how',
#   'more',
#   'onli',
#   'tri',
#   'wo',
#   'about',
#   'everi',
#   'much',
#   'lost',
#   'without',
#   'free',
#   'year',
#   'arm',
#   'goe',
#   'grow',
#   'becom',
#   'mad',
#   'somehow',
#   'imagin',
#   'sigh'],
#  'TRAADYI128E078FB38': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'love',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'when',
#   'like',
#   'now',
#   'can',
#   'come',
#   'there',
#   'up',
#   'one',
#   'they',
#   'down',
#   'get',
#   'she',
#   'see',
#   'if',
#   'got',
#   'from',
#   'he',
#   'way',
#   'take',
#   'as',
#   'ca',
#   'at',
#   'babi',
#   'yeah',
#   'y',
#   'back',
#   'by',
#   'her',
#   'how',
#   'night',
#   'need',
#   'our',
#   'eye',
#   'world',
#   'more',
#   'caus',
#   'right',
#   'tell',
#   'think',
#   'who',
#   'man',
#   'again',
#   'onli',
#   'tri',
#   'mind',
#   'us',
#   'his',
#   'some',
#   'over',
#   'then',
#   'said',
#   'did',
#   'home',
#   'walk',
#   'lie',
#   'end',
#   'cri',
#   'yo',
#   'these',
#   'last',
#   'off',
#   'show',
#   'lost',
#   'peopl',
#   'chorus',
#   'hard',
#   'even',
#   'put',
#   'own',
#   'fuck',
#   'close',
#   'star',
#   'while',
#   'high',
#   'two',
#   'onc',
#   'sound',
#   'everybodi',
#   'roll',
#   'son',
#   'ai',
#   'first',
#   'beat',
#   'money',
#   'air',
#   'fine',
#   'hit',
#   'men',
#   's',
#   'hous',
#   'went',
#   'meet',
#   'drink',
#   'cut',
#   'kid',
#   'nigga',
#   'floor',
#   'ladi',
#   'yet',
#   'hot',
#   'honey',
#   'parti',
#   'plus',
#   'brother',
#   'throw',
#   'goin',
#   'met',
#   'bone',
#   'piec',
#   '&',
#   'eat',
#   'second',
#   'jump',
#   'feed',
#   'front',
#   'safe',
#   'bar',
#   'ass',
#   'lift',
#   'treat',
#   'queen',
#   'okay',
#   'rather',
#   'tryin',
#   'mr',
#   'style',
#   'suppos',
#   'dime',
#   'par',
#   'grab',
#   'g',
#   'resist',
#   'niggaz',
#   'walkin',
#   'south',
#   'pound',
#   'suit',
#   'ima',
#   'motherfuck',
#   'favorit',
#   'toe',
#   'class',
#   'spot',
#   'w',
#   'playin',
#   'receiv',
#   'coat',
#   'cheek',
#   'whip',
#   'hop',
#   'chick',
# ...
#   'not',
#   'is',
#   'that',
#   'do',
#   'for',
#   'this',
#   'de',
#   'en',
#   'te',
#   'tu',
#   'whi',
#   'se',
#   'es',
#   'le',
#   'si',
#   'et',
#   'les',
#   'il',
#   'qui',
#   'pas',
#   'des',
#   'dan',
#   'mai',
#   'pour',
#   'ne',
#   'rest',
#   'cest',
#   'pay',
#   'nos',
#   'parti',
#   'plus',
#   'au',
#   'ce',
#   'comm',
#   'nous',
#   'ta',
#   'vie',
#   'entr',
#   'ell',
#   'grand',
#   'ou',
#   'ça',
#   'ton',
#   'fait',
#   'quon',
#   'tous',
#   'melodi',
#   'vill',
#   'sont',
#   'trop',
#   'quil',
#   'fort',
#   'cett',
#   'fruit',
#   'vent',
#   'soleil',
#   'content',
#   'gen',
#   'font',
#   'sest',
#   'peau',
#   'vieux',
#   'pluie',
#   'dautr'],
#  'TRAAGNS128E07824BD': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'do',
#   'on',
#   'are',
#   'for',
#   'no',
#   'know',
#   'with',
#   'just',
#   'come',
#   'there',
#   'they',
#   'down',
#   'get',
#   'was',
#   'got',
#   'want',
#   'here',
#   'how',
#   'where',
#   'tell',
#   'who',
#   'man',
#   'onli',
#   'keep',
#   'wo',
#   'his',
#   'some',
#   'littl',
#   'into',
#   'es',
#   'them',
#   'these',
#   'put',
#   'doe',
#   'side',
#   'rock',
#   'mayb',
#   'may',
#   'lone',
#   'ani',
#   'wall',
#   'game',
#   'ein',
#   'rest',
#   'went',
#   'noch',
#   'gave',
#   'peac',
#   'thank',
#   'eat',
#   'pictur',
#   'mein',
#   'slip',
#   'hole',
#   'ear',
#   'glass',
#   'wine',
#   'smell',
#   'poison',
#   'gettin',
#   'bitter',
#   'bet',
#   'torn',
#   'tall',
#   'offer',
#   'rot',
#   'makin',
#   'compani',
#   'coffe',
#   'rat',
#   'monday',
#   'tea',
#   'pot',
#   'chocol',
#   'plot',
#   'missin',
#   'spoil',
#   'lipstick'],
#  'TRAAGOZ128F92EB3D4': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'my',
#   'is',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'now',
#   'come',
#   'go',
#   'oh',
#   'out',
#   'see',
#   'never',
#   'feel',
#   'let',
#   'way',
#   'take',
#   'ca',
#   'at',
#   'yeah',
#   'back',
#   'heart',
#   'how',
#   'tell',
#   'think',
#   'too',
#   'tri',
#   'whi',
#   'mind',
#   'around',
#   'over',
#   'littl',
#   'turn',
#   'said',
#   'did',
#   'had',
#   'face',
#   'gone',
#   'everyth',
#   'has',
#   'insid',
#   'better',
#   'him',
#   'off',
#   'should',
#   'realli',
#   'hard',
#   'move',
#   'wrong',
#   'seem',
#   'own',
#   'someon',
#   'myself',
#   'mayb',
#   'hide',
#   'forget',
#   'understand',
#   'best',
#   'sometim',
#   'truth',
#   'els',
#   'fade',
#   'memori',
#   'strong',
#   'shake',
#   'cross',
#   'regret',
#   'remind',
#   'suppos',
#   'figur',
#   'oooh',
#   'eh',
#   'ooooh'],
#  'TRAAGPF12903CE027E': ['i',
#   'you',
#   'to',
#   'and',
#   'me',
#   'my',
#   'your',
#   'that',
#   'am',
#   'will',
#   'all',
#   'be',
#   'love',
#   'so',
#   'know',
#   'but',
#   'when',
#   'if',
#   'life',
#   'our',
#   'too',
#   'then',
#   'call',
#   'wait',
#   'hear',
#   'alon',
#   'blue',
#   'own',
#   'true',
#   'mean',
#   'clear',
#   'becom',
#   'ring',
#   'answer',
#   'dear',
#   'belong',
#   'echo',
#   'offer',
#   'refus'],
#  'TRAAGPJ128F428CD1B': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'do',
#   'on',
#   'are',
#   'am',
#   'all',
#   'no',
#   'be',
#   'have',
#   'love',
#   'so',
#   'know',
#   'just',
#   'when',
#   'like',
#   'up',
#   'they',
#   'if',
#   'never',
#   'from',
#   'say',
#   'would',
#   'as',
#   'ca',
#   'night',
#   'caus',
#   'gonna',
#   'die',
#   'right',
#   'man',
#   'too',
#   'or',
#   'whi',
#   'mind',
#   'wo',
#   'long',
#   'good',
#   'some',
#   'call',
#   'face',
#   'gone',
#   'word',
#   'place',
#   'anoth',
#   'care',
#   'move',
#   'wrong',
#   'put',
#   'free',
#   'gotta',
#   'talk',
#   'mine',
#   'fire',
#   'dead',
#   'mean',
#   'yes',
#   'smile',
#   'bad',
#   'togeth',
#   'came',
#   'ai',
#   'bed',
#   'cut',
#   'gun',
#   'stone',
#   'dog',
#   'pretend',
#   'dawn',
#   'spend',
#   'chain',
#   'ball',
#   'law',
#   'loos',
#   'poison',
#   'cruel',
#   'knife',
#   'cup',
#   'rope',
#   'leavin',
#   'shove',
#   'drank',
#   'dusk'],
#  'TRAAGSG128F92CFC6E': ['a',
#   'me',
#   'que',
#   'de',
#   'e',
#   'o',
#   'em',
#   'eu',
#   'mai',
#   'não',
#   'mas',
#   'um',
#   'nada',
#   'porqu',
#   'ver',
#   'sei',
#   'pra',
#   'dia',
#   'vai',
#   'com',
#   'só',
#   'os',
#   'amigo',
#   'nem',
#   'tard',
#   'mim',
#   'nas',
#   'ele',
#   'esperando',
#   'esperar',
#   'meus',
#   'num',
#   'fazer',
#   'sonho',
#   'isso',
#   'rua',
#   'sinto',
#   'pouco',
#   'acabar'],
#  'TRAAGTO128F1497E3C': ['i',
#   'you',
#   'and',
#   'me',
#   'it',
#   'in',
#   'your',
#   'we',
#   'am',
#   'will',
#   'know',
#   'but',
#   'what',
#   'when',
#   'time',
#   'can',
#   'see',
#   'life',
#   'again',
#   'too',
#   'light',
#   'stop',
#   'wrong',
#   'seem',
#   'touch',
#   'might',
#   'miss',
#   'sometim',
#   'learn',
#   'everyon',
#   'meet',
#   'fast'],
#  'TRAAGVM128E0784D95': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'be',
#   'have',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'when',
#   'like',
#   'now',
#   'time',
#   'can',
#   'up',
#   'they',
#   'out',
#   'down',
#   'get',
#   'see',
#   'if',
#   'never',
#   'from',
#   'he',
#   'let',
#   'make',
#   'way',
#   'say',
#   'take',
#   'ca',
#   'day',
#   'life',
#   'by',
#   'here',
#   'how',
#   'world',
#   'more',
#   'caus',
#   'gonna',
#   'man',
#   'give',
#   'onli',
#   'or',
#   'keep',
#   'mind',
#   'long',
#   'fall',
#   'about',
#   'some',
#   'hand',
#   'then',
#   'alway',
#   'did',
#   'them',
#   'face',
#   'believ',
#   'ya',
#   'their',
#   'place',
#   'last',
#   'friend',
#   'anoth',
#   'play',
#   'made',
#   'realli',
#   'chorus',
#   'pain',
#   'own',
#   'mine',
#   'dead',
#   'mean',
#   'breath',
#   'bad',
#   'sound',
#   'help',
#   'becaus',
#   'death',
#   'everybodi',
#   'may',
#   'ai',
#   'hurt',
#   'pass',
#   'ani',
#   'angel',
#   'chanc',
#   'part',
#   'sit',
#   'lay',
#   'shit',
#   'earth',
#   'rest',
#   'power',
#   'lot',
#   'sinc',
#   'kid',
#   'hour',
#   'sick',
#   'plan',
#   'mad',
#   'caught',
#   'damn',
#   'space',
#   'dress',
#   'minut',
#   'dont',
#   'spend',
#   'everyday',
#   'escap',
#   'grave',
#   'ass',
#   'vision',
#   'state',
#   'feelin',
#   'awak',
#   'taken',
#   'path',
#   'cat',
#   'doin',
#   'forgotten',
#   'victim',
#   'makin',
#   'prison',
#   'class',
#   'takin',
#   'limit',
#   'mission',
#   'burnin',
#   'normal',
#   'express',
#   'givin',
#   'inner',
#   'pair',
#   'rotten',
#   'neighbor',
#   'stray',
#   'visit',
#   'havin',
#   'turnin',
#   'lend',
#   'drama',
#   'oughta',
#   'wonderin',
#   'basement',
#   'powder'],
#  'TRAAGWV12903CF3709': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'of',
#   'that',
#   'do',
#   'are',
#   'we',
#   'am',
#   'all',
#   'for',
#   'have',
#   'know',
#   'but',
#   'what',
#   'just',
#   'when',
#   'like',
#   'now',
#   'time',
#   'up',
#   'they',
#   'get',
#   'see',
#   'never',
#   'from',
#   'want',
#   'make',
#   'would',
#   'yeah',
#   'back',
#   'could',
#   'look',
#   'been',
#   'through',
#   'live',
#   'give',
#   'tri',
#   'or',
#   'mind',
#   'about',
#   'some',
#   'turn',
#   'run',
#   'them',
#   'end',
#   'hey',
#   'someth',
#   'much',
#   'better',
#   'anoth',
#   'thought',
#   'start',
#   'should',
#   'without',
#   'bring',
#   'mean',
#   'doe',
#   'onc',
#   'togeth',
#   'yourself',
#   'hate',
#   'happi',
#   'seen',
#   'until',
#   'truth',
#   'kind',
#   'blind',
#   'along',
#   'shake',
#   'somebodi',
#   'pull',
#   'sinc',
#   'becom',
#   'known',
#   'fair',
#   'lookin',
#   'somehow',
#   'problem',
#   'curs',
#   'twice',
#   'bottom',
#   'wors',
#   'struggl',
#   'dumb',
#   'tail',
#   'ive',
#   'deaf'],
#  'TRAAGXU12903C9BE30': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'love',
#   'know',
#   'but',
#   'just',
#   'like',
#   'now',
#   'time',
#   'can',
#   'go',
#   'one',
#   'they',
#   'out',
#   'never',
#   'from',
#   'he',
#   'feel',
#   'let',
#   'way',
#   'say',
#   'as',
#   'at',
#   'babi',
#   'yeah',
#   'here',
#   'how',
#   'look',
#   'where',
#   'thing',
#   'more',
#   'caus',
#   'die',
#   'been',
#   'tell',
#   'through',
#   'too',
#   'onli',
#   'well',
#   'find',
#   'around',
#   'some',
#   'call',
#   'everi',
#   'alway',
#   'did',
#   'into',
#   'leav',
#   'walk',
#   'hear',
#   'has',
#   'alon',
#   'someth',
#   'better',
#   'left',
#   'off',
#   'lost',
#   'peopl',
#   'start',
#   'hope',
#   'seem',
#   'own',
#   'dark',
#   'other',
#   'must',
#   'year',
#   'ooh',
#   'roll',
#   'sure',
#   'goe',
#   'under',
#   'after',
#   'matter',
#   'rise',
#   'water',
#   'each',
#   'along',
#   'room',
#   'scream',
#   'control',
#   'everyon',
#   'promis',
#   'bed',
#   'skin',
#   'til',
#   'slow',
#   'clear',
#   'faith',
#   'fun',
#   'train',
#   'plan',
#   'throw',
#   'bone',
#   'second',
#   'scare',
#   'finger',
#   'comin',
#   'dri',
#   'phone',
#   'ear',
#   'paint',
#   'feelin',
#   'climb',
#   'stick',
#   'busi',
#   'reflect',
#   'grab',
#   'runnin',
#   'movin',
#   'attent',
#   'fallin',
#   'explod',
#   'exact',
#   'admit',
#   'ticket',
#   'twenti',
#   'nerv',
#   'grind',
#   'usual',
#   'deaf',
#   'swore',
#   'gear',
#   'safeti',
#   'missin',
#   'junki',
#   'ladder',
#   'wonderin',
#   'mold',
#   'rabbit',
#   'collar'],
#  'TRAAHBS128F429F76A': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'in',
#   'my',
#   'of',
#   'that',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'be',
#   'so',
#   'know',
#   'but',
#   'just',
#   'when',
#   'like',
#   'come',
#   'there',
#   'one',
#   'they',
#   'get',
#   'see',
#   'if',
#   'want',
#   'as',
#   'here',
#   'look',
#   'gonna',
#   'right',
#   'us',
#   'long',
#   'girl',
#   'wanna',
#   'littl',
#   'hand',
#   'everi',
#   'hold',
#   'ever',
#   'friend',
#   'anoth',
#   'song',
#   'real',
#   'two',
#   'mayb',
#   'mani',
#   'becaus',
#   'big',
#   'sea',
#   'su',
#   'three',
#   'cool',
#   'guy',
#   'four',
#   'yea',
#   'fish',
#   'stole',
#   'probabl',
#   'tini',
#   'screw'],
#  'TRAAHBU12903CB9E27': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'on',
#   'are',
#   'am',
#   'will',
#   'all',
#   'for',
#   'have',
#   'love',
#   'know',
#   'this',
#   'what',
#   'just',
#   'when',
#   'now',
#   'come',
#   'they',
#   'out',
#   'get',
#   'see',
#   'want',
#   'way',
#   'take',
#   'ca',
#   'life',
#   'look',
#   'caus',
#   'who',
#   'tri',
#   'mind',
#   'an',
#   'wo',
#   'littl',
#   'said',
#   'run',
#   'insid',
#   'chang',
#   'better',
#   'left',
#   'play',
#   'hope',
#   'tear',
#   'someon',
#   'yes',
#   'done',
#   'blood',
#   'enough',
#   'help',
#   'son',
#   'fool',
#   'blind',
#   'readi',
#   'past',
#   'scream',
#   'mother',
#   'troubl',
#   'knee',
#   'piec',
#   'slip',
#   'remain',
#   'dirti',
#   'scar',
#   'prove',
#   'trap',
#   'sugar',
#   'victim',
#   'diseas',
#   'trick',
#   'joke',
#   'whose',
#   'nose',
#   'lick',
#   'cage',
#   'rough',
#   'squeez',
#   'jive'],
#  'TRAAHCO128F14B0844': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'do',
#   'we',
#   'am',
#   'will',
#   'be',
#   'have',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'now',
#   'time',
#   'can',
#   'go',
#   'one',
#   'they',
#   'out',
#   'down',
#   'get',
#   'see',
#   'if',
#   'from',
#   'he',
#   'feel',
#   'let',
#   'say',
#   'take',
#   'would',
#   'ca',
#   'away',
#   'how',
#   'could',
#   'our',
#   'caus',
#   'tell',
#   'think',
#   'who',
#   'or',
#   'wo',
#   'still',
#   'his',
#   'turn',
#   'then',
#   'were',
#   'them',
#   'face',
#   'alon',
#   'someth',
#   'insid',
#   'word',
#   'place',
#   'him',
#   'burn',
#   'break',
#   'should',
#   'even',
#   'same',
#   'own',
#   'those',
#   'breath',
#   'fear',
#   'becaus',
#   'deep',
#   'grow',
#   'though',
#   'reach',
#   'such',
#   'wast',
#   'pull',
#   'power',
#   'tire',
#   'trust',
#   'tast',
#   'push',
#   'low',
#   'futur',
#   'flow',
#   'blame',
#   'against',
#   'sens',
#   'point',
#   'fate',
#   'forgiv',
#   'fail',
#   'somehow',
#   'choos',
#   'awak',
#   'buri',
#   'strength',
#   'decid',
#   'choic',
#   'proud',
#   'special',
#   'wont',
#   'weight',
#   'shape',
#   'crown',
#   'present',
#   'guilti',
#   'weari',
#   'loss',
#   'asham',
#   'failur',
#   'selfish',
#   'envi',
#   'shown',
#   'spite',
#   'cleans',
#   'rid',
#   'ident',
#   'virtu',
#   'combat'],
#  'TRAAHDK128F423BB26': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'is',
#   'your',
#   'that',
#   'do',
#   'are',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'love',
#   'with',
#   'like',
#   'up',
#   'one',
#   'get',
#   'if',
#   'from',
#   'want',
#   'take',
#   'would',
#   'ca',
#   'at',
#   'away',
#   'heart',
#   'here',
#   'how',
#   'look',
#   'eye',
#   'caus',
#   'onli',
#   'or',
#   'long',
#   'alway',
#   'did',
#   'hold',
#   'run',
#   'ever',
#   'face',
#   'end',
#   'cri',
#   'insid',
#   'place',
#   'anoth',
#   'peopl',
#   'hard',
#   'hope',
#   'dark',
#   'star',
#   'two',
#   'cold',
#   'blood',
#   'door',
#   'yourself',
#   'hate',
#   'hide',
#   'happi',
#   'understand',
#   'truth',
#   'follow',
#   'anyth',
#   'red',
#   'tomorrow',
#   's',
#   'lead',
#   'promis',
#   'window',
#   'second',
#   'minut',
#   'wash',
#   'mirror',
#   'reflect',
#   'total',
#   'gaze',
#   'drip',
#   'easier',
#   'fold',
#   'bedroom',
#   'balloon'],
#  'TRAAHDM128F429C0B1': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'not',
#   'my',
#   'your',
#   'on',
#   'are',
#   'be',
#   'with',
#   'can',
#   'one',
#   'down',
#   'see',
#   'never',
#   'take',
#   'life',
#   'by',
#   'how',
#   'look',
#   'more',
#   'mind',
#   'wanna',
#   'noth',
#   'alway',
#   'were',
#   'did',
#   'everyth',
#   'alon',
#   'chang',
#   'than',
#   'song',
#   'hide',
#   'save',
#   'tomorrow',
#   'tree',
#   'vow'],
#  'TRAAHEG128E07861C3': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'so',
#   'this',
#   'with',
#   'what',
#   'when',
#   'like',
#   'now',
#   'come',
#   'there',
#   'go',
#   'up',
#   'la',
#   'they',
#   'out',
#   'down',
#   'from',
#   'he',
#   'way',
#   'would',
#   'day',
#   'at',
#   'by',
#   'how',
#   'could',
#   'night',
#   'look',
#   'caus',
#   'right',
#   'tell',
#   'live',
#   'again',
#   'around',
#   'said',
#   'call',
#   'hold',
#   'run',
#   'walk',
#   'them',
#   'ya',
#   'yo',
#   'friend',
#   'new',
#   'than',
#   'play',
#   'hope',
#   'bring',
#   'fuck',
#   'cold',
#   'open',
#   'line',
#   'onc',
#   'ride',
#   'roll',
#   'son',
#   'ai',
#   'town',
#   'em',
#   'wall',
#   'air',
#   'water',
#   'citi',
#   'lay',
#   'shit',
#   'red',
#   'blow',
#   'pull',
#   'pay',
#   'hot',
#   'summer',
#   'troubl',
#   'wear',
#   'nowher',
#   'dog',
#   'build',
#   'comin',
#   'hole',
#   'radio',
#   'phone',
#   'shoe',
#   'ass',
#   'check',
#   'crack',
#   'spit',
#   'block',
#   'weather',
#   'highway',
#   'action',
#   'jack',
#   'niggaz',
#   'doctor',
#   'pound',
#   'motherfuck',
#   'clown',
#   'dick',
#   'piss',
#   'dj',
#   'callin',
#   'whip',
#   'brick',
#   'dope',
#   'funk',
#   'rob',
#   'ridin',
#   'stack',
#   'sourc',
#   'tap',
#   'fucker',
#   'duck',
#   'gear',
#   'memphi',
#   'dalla',
#   'chicago',
#   'fo',
#   'squad',
#   'stalk',
#   'kickin',
#   'beef',
#   'blunt'],
#  'TRAAHER128F92D0354': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'not',
#   'in',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'be',
#   'but',
#   'with',
#   'like',
#   'now',
#   'time',
#   'can',
#   'come',
#   'there',
#   'up',
#   'one',
#   'down',
#   'got',
#   'never',
#   'from',
#   'let',
#   'way',
#   'as',
#   'day',
#   'by',
#   'look',
#   'where',
#   'caus',
#   'been',
#   'or',
#   'whi',
#   'mind',
#   'find',
#   'some',
#   'said',
#   'home',
#   'gone',
#   'head',
#   'ya',
#   'has',
#   'hey',
#   'danc',
#   'must',
#   'sweet',
#   'rememb',
#   'star',
#   'yes',
#   'smile',
#   'cold',
#   'fli',
#   'sound',
#   'heaven',
#   'save',
#   'round',
#   'crazi',
#   'room',
#   'memori',
#   'child',
#   'slow',
#   'cool',
#   'wave',
#   'mile',
#   'share',
#   'drown',
#   'scare',
#   'longer',
#   'bar',
#   'corner',
#   'ago',
#   'chase',
#   'ship',
#   'shore',
#   'waitin',
#   'sayin',
#   'restless',
#   'callin',
#   'tellin',
#   'familiar',
#   'breakin',
#   'dreamin',
#   'pushin',
#   'jukebox'],
#  'TRAAHFR12903CA2491': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'my',
#   'is',
#   'your',
#   'on',
#   'for',
#   'have',
#   'love',
#   'know',
#   'just',
#   'like',
#   'feel',
#   'back',
#   'need',
#   'world',
#   'onli',
#   'dream',
#   'around',
#   'turn',
#   'alway',
#   'their',
#   'someth',
#   'than',
#   'burn',
#   'sky',
#   'watch',
#   'other',
#   'kiss',
#   'cold',
#   'fli',
#   'onc',
#   'door',
#   'miss',
#   'wind',
#   'chanc',
#   'blind',
#   'blow',
#   'secret',
#   'spirit',
#   'color',
#   'winter',
#   'bridg',
#   'mysteri',
#   'stronger',
#   'score',
#   'beam',
#   'slam',
#   'player',
#   'signal']}

# %%
# save dictionary to pickle
import pickle
with open('lyrics_dict.p', 'wb') as fp:
    pickle.dump(my_dict, fp)

# %%
with open('lyrics_dict.p', 'rb') as fp:
    data_pickle = pickle.load(fp)

# %%
# don't include this if posting to github

#data_pickle
# Out:
# {'TRAAAAV128F421A322': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'are',
#   'we',
#   'am',
#   'will',
#   'for',
#   'be',
#   'have',
#   'so',
#   'this',
#   'like',
#   'de',
#   'up',
#   'was',
#   'if',
#   'got',
#   'would',
#   'been',
#   'these',
#   'seem',
#   'someon',
#   'understand',
#   'pass',
#   'river',
#   'met',
#   'piec',
#   'damn',
#   'worth',
#   'flesh',
#   'grace',
#   'poor',
#   'somehow',
#   'ignor',
#   'passion',
#   'tide',
#   'season',
#   'seed',
#   'resist',
#   'order',
#   'piti',
#   'fashion',
#   'grant',
#   'captur',
#   'ici',
#   'soil',
#   'patienc',
#   'social',
#   'highest',
#   'slice',
#   'leaf',
#   'lifeless',
#   'arrang',
#   'wilder',
#   'shark',
#   'devast',
#   'element'],
#  'TRAAABD128F429CF47': ['i',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'your',
#   'that',
#   'do',
#   'are',
#   'for',
#   'no',
#   'have',
#   'so',
#   'know',
#   'but',
#   'what',
#   'when',
#   'time',
#   'can',
#   'there',
#   'la',
#   'get',
#   'got',
#   'never',
#   'feel',
#   'want',
#   'would',
#   'day',
#   'away',
#   'yeah',
#   'heart',
#   'could',
#   'need',
#   'our',
#   'look',
#   'where',
#   'thing',
#   'think',
#   'live',
#   'onli',
#   'tri',
#   'keep',
#   'dream',
#   'wanna',
#   'find',
#   'hear',
#   'believ',
#   'everyth',
#   'someth',
#   'insid',
#   'chang',
#   'soul',
#   'new',
#   'start',
#   'pleas',
#   'true',
#   'while',
#   'deep',
#   'beat',
#   'after',
#   'fade',
#   'wast',
#   'trust',
#   'alreadi',
#   'style',
#   'asleep',
#   'wors',
#   'goal'],
#  'TRAAAED128E0783FAB': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'do',
#   'on',
#   'are',
#   'am',
#   'will',
#   'for',
#   'be',
#   'have',
#   'love',
#   'so',
#   'this',
#   'but',
#   'just',
#   'when',
#   'like',
#   'time',
#   'come',
#   'go',
#   'one',
#   'out',
#   'down',
#   'if',
#   'got',
#   'from',
#   'feel',
#   'make',
#   'way',
#   'take',
#   'day',
#   'by',
#   'her',
#   'heart',
#   'could',
#   'look',
#   'where',
#   'more',
#   'been',
#   'who',
#   'through',
#   'onli',
#   'tri',
#   'whi',
#   'dream',
#   'well',
#   'an',
#   'long',
#   'girl',
#   'find',
#   'good',
#   'about',
#   'some',
#   'littl',
#   'wait',
#   'run',
#   'walk',
#   'gone',
#   'someth',
#   'befor',
#   'much',
#   'anoth',
#   'new',
#   'tonight',
#   'burn',
#   'thought',
#   'realli',
#   'hard',
#   'care',
#   'put',
#   'seem',
#   'mine',
#   'fire',
#   'someon',
#   'while',
#   'doe',
#   'smile',
#   'open',
#   'door',
#   'mayb',
#   'may',
#   'sometim',
#   'lone',
#   'chanc',
#   'air',
#   'water',
#   'readi',
#   'past',
#   'happen',
#   'pretti',
#   'differ',
#   'faith',
#   'search',
#   'flame',
#   'piec',
#   'cos',
#   'meant',
#   'higher',
#   'edg',
#   'surpris',
#   'person',
#   'twice',
#   'noon',
#   'thin',
#   'celebr',
#   'inspir',
#   'advic',
#   'ideal'],
#  'TRAAAEF128F4273421': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'not',
#   'is',
#   'of',
#   'that',
#   'do',
#   'are',
#   'for',
#   'know',
#   'this',
#   'with',
#   'when',
#   'can',
#   'she',
#   'if',
#   'got',
#   'from',
#   'feel',
#   'let',
#   'would',
#   'her',
#   'eye',
#   'world',
#   'right',
#   'think',
#   'through',
#   'or',
#   'wo',
#   'girl',
#   'everi',
#   'had',
#   'has',
#   'someth',
#   'tonight',
#   'old',
#   'boy',
#   'mine',
#   'someon',
#   'star',
#   'while',
#   'wish',
#   'smile',
#   'shine',
#   'yourself',
#   'ask',
#   'white',
#   'three',
#   'send',
#   'treat',
#   'relax',
#   'tip',
#   'pearl',
#   'curl',
#   'adam'],
#  'TRAAAEW128F42930C0': ['i',
#   'to',
#   'and',
#   'a',
#   'me',
#   'not',
#   'in',
#   'my',
#   'that',
#   'on',
#   'am',
#   'all',
#   'with',
#   'like',
#   'up',
#   'take',
#   'would',
#   'or',
#   'an',
#   'wo',
#   'someth',
#   'stay',
#   'burn',
#   'made',
#   'use',
#   'someon',
#   'those',
#   'breath',
#   'done',
#   'touch',
#   'bodi',
#   'fade',
#   'sad',
#   'stone',
#   'tight',
#   'space',
#   'color',
#   'mess',
#   'tie',
#   'paint',
#   'cast',
#   'fix',
#   'bend',
#   'melt',
#   'grey',
#   'ash',
#   'wire',
#   'liar',
#   'stain',
#   'wet',
#   'mix',
#   'numb',
#   'rust',
#   'burnt',
#   'debt',
#   'lifeless',
#   'dissolv',
#   'mold',
#   'clay',
#   'print',
#   'wax',
#   'ink',
#   'leak'],
#  'TRAAAFD128F92F423A': ['i',
#   'the',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'do',
#   'on',
#   'are',
#   'am',
#   'all',
#   'for',
#   'no',
#   'have',
#   'this',
#   'just',
#   'now',
#   'there',
#   'one',
#   'got',
#   'never',
#   'from',
#   'feel',
#   'way',
#   'take',
#   'would',
#   'away',
#   'how',
#   'could',
#   'world',
#   'caus',
#   'die',
#   'been',
#   'think',
#   'again',
#   'dream',
#   'his',
#   'over',
#   'turn',
#   'then',
#   'walk',
#   'face',
#   'word',
#   'place',
#   'better',
#   'him',
#   'someon',
#   'those',
#   'while',
#   'kill',
#   'done',
#   'matter',
#   'lay',
#   'red',
#   'memori',
#   'tire',
#   'clear',
#   'felt',
#   'secret',
#   'wave',
#   'mouth',
#   'win',
#   'exist',
#   'swear',
#   'none',
#   'ash',
#   'ador',
#   'eras',
#   'worst',
#   'sale',
#   'settl',
#   'seal',
#   'worn',
#   'limb',
#   'concern',
#   'runaway'],
#  'TRAAAGF12903CEC202': ['en',
#   'e',
#   'end',
#   'du',
#   'et',
#   'fine',
#   'som',
#   'n',
#   'ei',
#   'og',
#   'så',
#   'mot',
#   'min',
#   'din',
#   'alt',
#   'inn',
#   'leve',
#   'når',
#   'gi'],
#  'TRAAAHJ128F931194C': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'in',
#   'my',
#   'of',
#   'your',
#   'do',
#   'on',
#   'we',
#   'am',
#   'for',
#   'be',
#   'love',
#   'this',
#   'just',
#   'when',
#   'now',
#   'time',
#   'can',
#   'out',
#   'never',
#   'say',
#   'day',
#   'at',
#   'away',
#   'back',
#   'heart',
#   'here',
#   'how',
#   'world',
#   'onli',
#   'an',
#   'long',
#   'turn',
#   'hand',
#   'walk',
#   'cri',
#   'word',
#   'these',
#   'last',
#   'close',
#   'breath',
#   'wish',
#   'war',
#   'beat',
#   'angel',
#   'reach',
#   'step',
#   'memori',
#   'apart',
#   'speak',
#   'til',
#   'afraid',
#   'wave',
#   'bone',
#   'wing',
#   'rose',
#   'shame',
#   'forgiv',
#   'loud',
#   'sail',
#   'bridg',
#   'dare',
#   'torn',
#   'echo',
#   'sigh',
#   'nake',
#   'sunset',
#   'delight',
#   'thorn',
#   'sharp',
#   'stir',
#   'solitud',
#   'fleet'],
#  'TRAAAHZ128E0799171': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'all',
#   'for',
#   'no',
#   'have',
#   'love',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'when',
#   'like',
#   'now',
#   'time',
#   'can',
#   'come',
#   'go',
#   'up',
#   'one',
#   'they',
#   'out',
#   'down',
#   'get',
#   'was',
#   'see',
#   'got',
#   'never',
#   'from',
#   'feel',
#   'want',
#   'way',
#   'say',
#   'as',
#   'ca',
#   'at',
#   'yeah',
#   'back',
#   'heart',
#   'here',
#   'night',
#   'need',
#   'look',
#   'world',
#   'more',
#   'caus',
#   'right',
#   'been',
#   'tell',
#   'man',
#   'live',
#   'again',
#   'give',
#   'too',
#   'onli',
#   'whi',
#   'dream',
#   'around',
#   'good',
#   'about',
#   'some',
#   'over',
#   'leav',
#   'had',
#   'gone',
#   'stay',
#   'god',
#   'these',
#   'new',
#   'him',
#   'stop',
#   'burn',
#   'sun',
#   'off',
#   'play',
#   'made',
#   'start',
#   'hard',
#   'boy',
#   'put',
#   'name',
#   'same',
#   'fuck',
#   'other',
#   'rememb',
#   'star',
#   'yes',
#   'real',
#   'two',
#   'black',
#   'rock',
#   'shine',
#   'heaven',
#   'work',
#   'big',
#   'street',
#   'came',
#   'till',
#   'deep',
#   'happi',
#   'ai',
#   'best',
#   'listen',
#   'hell',
#   'set',
#   'em',
#   'pass',
#   'fool',
#   'chanc',
#   'part',
#   'nobodi',
#   'game',
#   'though',
#   'each',
#   'young',
#   'readi',
#   'shit',
#   'along',
#   'hit',
#   'happen',
#   'whole',
#   'car',
#   'pray',
#   'gave',
#   'tire',
#   'lot',
#   'sinc',
#   'kid',
#   'nigga',
#   'hot',
#   'bright',
#   'secret',
#   'push',
#   'three',
#   'drop',
#   'wear',
#   'uh',
#   'thank',
#   'catch',
#   'fell',
#   'top',
#   'cover',
#   'write',
#   'number',
#   'lock',
#   'bless',
#   'knock',
#   'four',
#   'check',
#   'famili',
#   'choos',
#   'small',
#   'wit',
#   'swear',
#   'yall',
#   'c',
#   'kept',
#   'busi',
#   'price',
#   'trip',
#   'shoulder',
#   'tune',
#   'pop',
#   'wife',
#   'bite',
#   'west',
#   'block',
#   'g',
#   'direct',
#   'rap',
#   'laid',
#   'clock',
#   'paid',
#   'yellow',
#   'judg',
#   'doubl',
#   'wise',
#   'mom',
#   'older',
#   'motherfuck',
#   'spot',
#   'beach',
#   'aw',
#   'throne',
#   'steadi',
#   'handl',
#   'coast',
#   'mic',
#   'boss',
#   'weed',
#   'presenc',
#   'jail',
#   'grind',
#   'buck',
#   'righteous',
#   'sharp',
#   'playa',
#   'famous',
#   'colder',
#   'file',
#   'local',
#   'process',
#   'bid',
#   'profit'],
#  'TRAAAJG128F9308A25': ['i',
#   'the',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'is',
#   'that',
#   'do',
#   'on',
#   'are',
#   'for',
#   'have',
#   'so',
#   'but',
#   'like',
#   'can',
#   'one',
#   'get',
#   'from',
#   'ca',
#   'here',
#   'need',
#   'world',
#   'die',
#   'give',
#   'too',
#   'tri',
#   'walk',
#   'end',
#   'much',
#   'stand',
#   'old',
#   'without',
#   'pain',
#   'myself',
#   'rain',
#   'cold',
#   'bad',
#   'mani',
#   'goe',
#   'young',
#   'kid',
#   'bleed',
#   'somewher',
#   'bitter',
#   'protect',
#   'hungri',
#   'order',
#   'although',
#   'coat',
#   'helpless',
#   'complain',
#   'defend'],
#  'TRAAAOF128F429C156': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'on',
#   'we',
#   'am',
#   'will',
#   'all',
#   'no',
#   'have',
#   'so',
#   'know',
#   'what',
#   'just',
#   'when',
#   'like',
#   'now',
#   'can',
#   'come',
#   'there',
#   'go',
#   'up',
#   'oh',
#   'one',
#   'they',
#   'out',
#   'was',
#   'see',
#   'got',
#   'from',
#   'he',
#   'feel',
#   'say',
#   'day',
#   'at',
#   'yeah',
#   'back',
#   'our',
#   'look',
#   'right',
#   'man',
#   'onli',
#   'whi',
#   'his',
#   'long',
#   'girl',
#   'some',
#   'over',
#   'littl',
#   'were',
#   'leav',
#   'home',
#   'had',
#   'them',
#   'face',
#   'head',
#   'their',
#   'stay',
#   'place',
#   'better',
#   'last',
#   'him',
#   'tonight',
#   'off',
#   'start',
#   'realli',
#   'even',
#   'put',
#   'seem',
#   'other',
#   'high',
#   'came',
#   'everybodi',
#   'until',
#   'saw',
#   'ha',
#   'heard',
#   'soon',
#   'guess',
#   'full',
#   'king',
#   'tree',
#   'kid',
#   'near',
#   'honey',
#   'perfect',
#   'hair',
#   'knee',
#   'share',
#   'top',
#   'kick',
#   'guy',
#   'whoa',
#   'million',
#   'jump',
#   'snow',
#   'everywher',
#   'sand',
#   'hello',
#   'state',
#   'school',
#   'scene',
#   'spread',
#   'luck',
#   'pop',
#   'doin',
#   'huh',
#   'ooo',
#   'saturday',
#   'woo',
#   'beach',
#   'scratch',
#   'whip',
#   'hop',
#   'aah',
#   'hmm',
#   'bop',
#   'wow',
#   'flip',
#   'blowin',
#   'muscl',
#   'filthi',
#   'local',
#   'wah',
#   'oooo',
#   'yah',
#   'aaah',
#   'jumpin',
#   'eventu',
#   'comb'],
#  'TRAAARJ128F9320760': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'your',
#   'that',
#   'on',
#   'will',
#   'all',
#   'for',
#   'no',
#   'have',
#   'so',
#   'but',
#   'with',
#   'when',
#   'like',
#   'now',
#   'time',
#   'there',
#   'up',
#   'one',
#   'they',
#   'down',
#   'say',
#   'would',
#   'at',
#   'away',
#   'yeah',
#   'by',
#   'need',
#   'world',
#   'caus',
#   'an',
#   'wo',
#   'still',
#   'us',
#   'littl',
#   'call',
#   'leav',
#   'them',
#   'end',
#   'hear',
#   'their',
#   'friend',
#   'realli',
#   'seem',
#   'close',
#   'while',
#   'yes',
#   'onc',
#   'today',
#   'roll',
#   'listen',
#   'sea',
#   'citi',
#   'hous',
#   'laugh',
#   'blow',
#   'carri',
#   'anymor',
#   'sign',
#   'read',
#   'point',
#   'finger',
#   'comin',
#   'hill',
#   'quiet',
#   'rich',
#   'stood',
#   'bill',
#   'card',
#   'store',
#   'settl',
#   'sayin',
#   'admit',
#   'pink',
#   'sweep',
#   'repent',
#   'proof',
#   'factori',
#   'credit',
#   'villag'],
#  'TRAAAUC128F428716F': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'are',
#   'we',
#   'all',
#   'be',
#   'have',
#   'love',
#   'when',
#   'time',
#   'can',
#   'there',
#   'up',
#   'heart',
#   'where',
#   'tell',
#   'live',
#   'wo',
#   'then',
#   'light',
#   'call',
#   'home',
#   'hear',
#   'place',
#   'much',
#   'left',
#   'new',
#   'than',
#   'chorus',
#   'own',
#   'mine',
#   'tear',
#   'use',
#   'rememb',
#   'kiss',
#   'open',
#   'mayb',
#   'broken',
#   'fade',
#   'nobodi',
#   'memori',
#   'hous',
#   'somebodi',
#   'meet',
#   'apart',
#   'sinc',
#   'afraid',
#   'window',
#   'piec',
#   'drown',
#   'everyday',
#   'wine',
#   'dove',
#   'sweeter'],
#  'TRAAAZF12903CCCF6B': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'your',
#   'that',
#   'on',
#   'are',
#   'am',
#   'will',
#   'have',
#   'so',
#   'but',
#   'what',
#   'like',
#   'now',
#   'down',
#   'get',
#   'she',
#   'was',
#   'see',
#   'if',
#   'got',
#   'never',
#   'feel',
#   'want',
#   'let',
#   'say',
#   'at',
#   'away',
#   'her',
#   'night',
#   'look',
#   'gonna',
#   'tell',
#   'whi',
#   'keep',
#   'dream',
#   'wo',
#   'girl',
#   'find',
#   'over',
#   'littl',
#   'said',
#   'did',
#   'had',
#   'hold',
#   'run',
#   'ya',
#   'last',
#   'anoth',
#   'break',
#   'move',
#   'mean',
#   'doe',
#   'work',
#   'touch',
#   'behind',
#   'ai',
#   'under',
#   'ground',
#   'road',
#   'reason',
#   'nobodi',
#   'past',
#   'meet',
#   'pray',
#   'slow',
#   'fast',
#   'nothin',
#   'clean',
#   'sail',
#   'drag',
#   'runnin',
#   'noon',
#   'boat',
#   'movin',
#   'row',
#   'china',
#   'wilder',
#   'rocki',
#   'stride'],
#  'TRAABEV12903CC53A4': ['the',
#   'to',
#   'a',
#   'in',
#   'your',
#   'on',
#   'time',
#   'caus',
#   'face',
#   'head',
#   'place',
#   'pain',
#   'wrong',
#   'dead',
#   'real',
#   'fear',
#   'blood',
#   'gun',
#   'scare',
#   'disgrac'],
#  'TRAABHB12903CAFC2F': ['i',
#   'the',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'in',
#   'is',
#   'of',
#   'that',
#   'do',
#   'on',
#   'am',
#   'all',
#   'for',
#   'love',
#   'so',
#   'what',
#   'now',
#   'time',
#   'go',
#   'they',
#   'was',
#   'from',
#   'he',
#   'take',
#   'away',
#   'by',
#   'our',
#   'look',
#   'an',
#   'his',
#   'some',
#   'littl',
#   'then',
#   'had',
#   'face',
#   'alon',
#   'god',
#   'left',
#   'him',
#   'made',
#   'far',
#   'rain',
#   'rememb',
#   'line',
#   'onc',
#   'until',
#   'saw',
#   'soon',
#   'feet',
#   'empti',
#   'stone',
#   'cool',
#   'ten',
#   'mirror',
#   'spread',
#   'crime',
#   'vain',
#   'view',
#   'proud',
#   'sent',
#   'draw',
#   'mass',
#   'horizon',
#   'becam',
#   'silli',
#   'claw',
#   'coin',
#   'product',
#   'idol',
#   'poet',
#   'plea',
#   'dreamt',
#   'subject',
#   'lili'],
#  'TRAABHC128F933A3F8': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'for',
#   'be',
#   'know',
#   'with',
#   'just',
#   'like',
#   'time',
#   'go',
#   'up',
#   'oh',
#   'they',
#   'out',
#   'down',
#   'want',
#   'make',
#   'as',
#   'day',
#   'away',
#   'here',
#   'night',
#   'our',
#   'where',
#   'eye',
#   'right',
#   'through',
#   'too',
#   'well',
#   'find',
#   'fall',
#   'around',
#   'littl',
#   'wait',
#   'hold',
#   'run',
#   'them',
#   'stay',
#   'anoth',
#   'sun',
#   'off',
#   'sky',
#   'hope',
#   'watch',
#   'same',
#   'own',
#   'other',
#   'forev',
#   'close',
#   'kiss',
#   'two',
#   'open',
#   'il',
#   'side',
#   'fli',
#   'found',
#   'onc',
#   'togeth',
#   'shine',
#   'mani',
#   'morn',
#   'sit',
#   'fade',
#   'follow',
#   'wake',
#   'blind',
#   'each',
#   'reach',
#   'soon',
#   'abov',
#   'tree',
#   'differ',
#   'summer',
#   'outsid',
#   'cos',
#   'spend',
#   'slowli',
#   'besid',
#   'remind',
#   'below',
#   'wrap',
#   'weather',
#   'seed',
#   'underneath',
#   'breez',
#   'wherev',
#   'creep',
#   'w',
#   'pink',
#   'collid',
#   'mate',
#   'grain',
#   'pine',
#   'branch'],
#  'TRAABIG128F9356C56': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'am',
#   'all',
#   'for',
#   'no',
#   'have',
#   'love',
#   'so',
#   'know',
#   'this',
#   'but',
#   'what',
#   'when',
#   'like',
#   'now',
#   'time',
#   'can',
#   'there',
#   'up',
#   'oh',
#   'they',
#   'out',
#   'down',
#   'get',
#   'she',
#   'was',
#   'if',
#   'got',
#   'never',
#   'he',
#   'feel',
#   'make',
#   'say',
#   'take',
#   'would',
#   'as',
#   'babi',
#   'life',
#   'yeah',
#   'back',
#   'by',
#   'her',
#   'heart',
#   'look',
#   'eye',
#   'world',
#   'die',
#   'think',
#   'live',
#   'give',
#   'or',
#   'dream',
#   'an',
#   'his',
#   'girl',
#   'wanna',
#   'find',
#   'about',
#   'over',
#   'littl',
#   'then',
#   'noth',
#   'everi',
#   'did',
#   'had',
#   'walk',
#   'ever',
#   'hear',
#   'cri',
#   'hey',
#   'place',
#   'stand',
#   'anoth',
#   'play',
#   'thought',
#   'sing',
#   'start',
#   'realli',
#   'da',
#   'even',
#   'pleas',
#   'watch',
#   'gotta',
#   'talk',
#   'own',
#   'bring',
#   'someon',
#   'high',
#   'doe',
#   'year',
#   'fli',
#   'black',
#   'lose',
#   'wonder',
#   'help',
#   'work',
#   'street',
#   'hide',
#   'everybodi',
#   'town',
#   'listen',
#   'first',
#   'beat',
#   'goodby',
#   'wall',
#   'sit',
#   'scream',
#   'sad',
#   'laugh',
#   'went',
#   'meet',
#   'hang',
#   'mother',
#   'speak',
#   'stori',
#   'cannot',
#   'window',
#   'dear',
#   'outsid',
#   'across',
#   'caught',
#   'father',
#   'win',
#   'sens',
#   'space',
#   'drown',
#   'scare',
#   'daddi',
#   'dont',
#   'pa',
#   'ten',
#   'knock',
#   'silent',
#   'soft',
#   'shout',
#   'ba',
#   'five',
#   'silver',
#   'livin',
#   'float',
#   'figur',
#   'spent',
#   'drum',
#   'sudden',
#   'echo',
#   'attack',
#   'idea',
#   'clock',
#   'daughter',
#   'joke',
#   'wipe',
#   'screen',
#   'tick',
#   'spoke',
#   '10',
#   'screw',
#   'measur',
#   'pitch'],
#  'TRAABJS128F9325C99': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'me',
#   'that',
#   'will',
#   'for',
#   'be',
#   'so',
#   'what',
#   'when',
#   'come',
#   'there',
#   'one',
#   'she',
#   'want',
#   'way',
#   'say',
#   'by',
#   'her',
#   'eye',
#   'tell',
#   'still',
#   'turn',
#   'light',
#   'wait',
#   'hold',
#   'hard',
#   'wrong',
#   'free',
#   'fire',
#   'line',
#   'onc',
#   'save',
#   'sea',
#   'saw',
#   'white',
#   'bone',
#   'warm',
#   'gold',
#   'write',
#   'letter',
#   'stood',
#   'page',
#   'sacrific',
#   'tale',
#   'heartbreak',
#   'fairi'],
#  'TRAABJV128F1460C49': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'my',
#   'is',
#   'do',
#   'on',
#   'we',
#   'am',
#   'will',
#   'all',
#   'no',
#   'be',
#   'have',
#   'love',
#   'so',
#   'but',
#   'just',
#   'time',
#   'can',
#   'come',
#   'oh',
#   'out',
#   'down',
#   'see',
#   'if',
#   'feel',
#   'want',
#   'let',
#   'make',
#   'say',
#   'take',
#   'babi',
#   'heart',
#   'here',
#   'our',
#   'where',
#   'caus',
#   'gonna',
#   'been',
#   'tell',
#   'think',
#   'again',
#   'keep',
#   'well',
#   'us',
#   'long',
#   'girl',
#   'wanna',
#   'about',
#   'littl',
#   'ya',
#   'has',
#   'soul',
#   'tonight',
#   'play',
#   'break',
#   'move',
#   'fire',
#   'use',
#   'real',
#   'sound',
#   'ride',
#   'till',
#   'town',
#   'set',
#   'alright',
#   'game',
#   'anyth',
#   'strong',
#   'great',
#   'honey',
#   'cool',
#   'darl',
#   'mad',
#   'rule',
#   'desir',
#   'midnight',
#   'highway',
#   'celebr'],
#  'TRAABLR128F423B7E3': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'do',
#   'on',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'be',
#   'love',
#   'so',
#   'know',
#   'but',
#   'with',
#   'just',
#   'like',
#   'now',
#   'go',
#   'feel',
#   'at',
#   'life',
#   'by',
#   'night',
#   'need',
#   'right',
#   'tell',
#   'live',
#   'give',
#   'or',
#   'keep',
#   'well',
#   'still',
#   'us',
#   'fall',
#   'everi',
#   'leav',
#   'their',
#   'these',
#   'lost',
#   'hard',
#   'song',
#   'free',
#   'same',
#   'blue',
#   'own',
#   'tear',
#   'use',
#   'mean',
#   'line',
#   'came',
#   'ask',
#   'forget',
#   'best',
#   'hurt',
#   'music',
#   'late',
#   'wall',
#   'lead',
#   'drink',
#   'fast',
#   'tast',
#   'throw',
#   'goin',
#   'both',
#   'share',
#   'strang',
#   'yea',
#   'sink',
#   'remind',
#   'float',
#   'written',
#   'swim',
#   'brown',
#   'colour',
#   'gift',
#   'stain',
#   'refus',
#   'cigarett',
#   'convers',
#   'vocal',
#   'possibl',
#   'complain',
#   'collect',
#   'pool',
#   'product',
#   'william',
#   'produc',
#   'french',
#   'insist'],
#  'TRAABOA128F933684A': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'do',
#   'on',
#   'are',
#   'we',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'love',
#   'so',
#   'this',
#   'with',
#   'can',
#   'come',
#   'there',
#   'up',
#   'one',
#   'they',
#   'see',
#   'got',
#   'from',
#   'he',
#   'say',
#   'take',
#   'ca',
#   'away',
#   'life',
#   'yeah',
#   'heart',
#   'our',
#   'look',
#   'thing',
#   'whi',
#   'his',
#   'call',
#   'much',
#   'better',
#   'sing',
#   'peopl',
#   'song',
#   'hope',
#   'free',
#   'togeth',
#   'help',
#   'work',
#   'set',
#   'earth',
#   'somebodi',
#   'pray',
#   'king',
#   'answer',
#   'brother',
#   'father',
#   'dem',
#   'question',
#   'sister',
#   'prais',
#   'queen',
#   'book',
#   'prayer',
#   'special',
#   'thunder',
#   'youth',
#   'b',
#   'stole',
#   'jah',
#   'lightn',
#   'creation',
#   'treasur',
#   'common',
#   'lion',
#   'goal',
#   'sucker',
#   'equal',
#   'shook',
#   'achiev',
#   'background',
#   'almighti',
#   'gutter',
#   'captiv',
#   'pollut',
#   'majesti',
#   'uniti',
#   'assur'],
#  'TRAABOG128F42955B1': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'that',
#   'do',
#   'on',
#   'am',
#   'will',
#   'be',
#   'so',
#   'this',
#   'with',
#   'just',
#   'can',
#   'up',
#   'one',
#   'they',
#   'down',
#   'get',
#   'was',
#   'got',
#   'feel',
#   'want',
#   'say',
#   'day',
#   'at',
#   'babi',
#   'life',
#   'how',
#   'world',
#   'more',
#   'right',
#   'through',
#   'give',
#   'wanna',
#   'around',
#   'some',
#   'over',
#   'walk',
#   'much',
#   'god',
#   'soul',
#   'new',
#   'burn',
#   'break',
#   'start',
#   'hard',
#   'gotta',
#   'line',
#   'door',
#   'today',
#   'street',
#   'follow',
#   'citi',
#   'sad',
#   'cut',
#   'silenc',
#   'tast',
#   'bone',
#   'tight',
#   'million',
#   'shot',
#   'stranger',
#   'few',
#   'brand',
#   'wrap',
#   'march',
#   'york',
#   'grown',
#   'saint',
#   'loneli',
#   'concret',
#   'stair',
#   'standin',
#   'holdin',
#   'avenu',
#   'parasit',
#   'spanish',
#   'rome',
#   'ember'],
#  'TRAABPG128F14774DD': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'love',
#   'so',
#   'this',
#   'with',
#   'what',
#   'just',
#   'come',
#   'go',
#   'up',
#   'one',
#   'out',
#   'get',
#   'see',
#   'if',
#   'got',
#   'never',
#   'want',
#   'make',
#   'heart',
#   'look',
#   'who',
#   'through',
#   'whi',
#   'fall',
#   'lie',
#   'face',
#   'their',
#   'word',
#   'better',
#   'soul',
#   'than',
#   'play',
#   'care',
#   'name',
#   'talk',
#   'someon',
#   'sweet',
#   'kiss',
#   'smile',
#   'done',
#   'ooh',
#   'wonder',
#   'enough',
#   'work',
#   'everybodi',
#   'sometim',
#   'easi',
#   'game',
#   'along',
#   'crazi',
#   'hit',
#   'everyon',
#   'fun',
#   'perfect',
#   'secret',
#   'catch',
#   'shame',
#   'cos',
#   'tie',
#   'higher',
#   'paint',
#   'stranger',
#   'tongu',
#   'funni',
#   'sex',
#   'quick',
#   'fix',
#   'expect',
#   'gentl',
#   'further'],
#  'TRAABVM128F92CA9DC': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'love',
#   'so',
#   'know',
#   'this',
#   'with',
#   'what',
#   'just',
#   'like',
#   'now',
#   'can',
#   'come',
#   'up',
#   'one',
#   'down',
#   'get',
#   'was',
#   'if',
#   'from',
#   'make',
#   'way',
#   'take',
#   'as',
#   'day',
#   'away',
#   'life',
#   'here',
#   'how',
#   'eye',
#   'thing',
#   'world',
#   'gonna',
#   'die',
#   'right',
#   'tell',
#   'who',
#   'through',
#   'live',
#   'keep',
#   'dream',
#   'well',
#   'everi',
#   'face',
#   'everyth',
#   'chang',
#   'god',
#   'these',
#   'anoth',
#   'sun',
#   'thought',
#   'peopl',
#   'without',
#   'pain',
#   'seem',
#   'true',
#   'close',
#   'kiss',
#   'wish',
#   'done',
#   'mayb',
#   'heaven',
#   'big',
#   'everybodi',
#   'happi',
#   'ai',
#   'hurt',
#   'alright',
#   'sea',
#   'under',
#   'reason',
#   'aliv',
#   'earth',
#   'abov',
#   'whole',
#   'mother',
#   'cannot',
#   'brother',
#   'share',
#   'caught',
#   'father',
#   'brain',
#   'someday',
#   'color',
#   'race',
#   'feelin',
#   'sister',
#   'imagin',
#   'sent',
#   'fantasi',
#   'among',
#   'creatur',
#   'simpli',
#   'imposs',
#   'givin',
#   'harmoni',
#   'everlast',
#   'daydream'],
#  'TRAABXH128F42955D6': ['i',
#   'the',
#   'you',
#   'and',
#   'a',
#   'it',
#   'in',
#   'my',
#   'your',
#   'on',
#   'we',
#   'am',
#   'will',
#   'be',
#   'so',
#   'this',
#   'can',
#   'say',
#   'as',
#   'at',
#   'could',
#   'look',
#   'eye',
#   'thing',
#   'through',
#   'keep',
#   'an',
#   'still',
#   'find',
#   'said',
#   'wait',
#   'them',
#   'hear',
#   'word',
#   'last',
#   'far',
#   'tear',
#   'those',
#   'year',
#   'music',
#   'goodby',
#   'though',
#   'soon',
#   'apart',
#   'summer',
#   'futur',
#   'most',
#   'letter',
#   'screen',
#   'date',
#   'sincer',
#   'septemb'],
#  'TRAACER128F4290F96': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'of',
#   'your',
#   'do',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'be',
#   'have',
#   'so',
#   'know',
#   'this',
#   'but',
#   'just',
#   'like',
#   'can',
#   'come',
#   'there',
#   'go',
#   'up',
#   'they',
#   'down',
#   'see',
#   'never',
#   'feel',
#   'let',
#   'say',
#   'take',
#   'babi',
#   'yeah',
#   'back',
#   'heart',
#   'could',
#   'night',
#   'look',
#   'where',
#   'eye',
#   'world',
#   'caus',
#   'gonna',
#   'right',
#   'think',
#   'well',
#   'wo',
#   'long',
#   'wanna',
#   'find',
#   'over',
#   'noth',
#   'everi',
#   'into',
#   'leav',
#   'home',
#   'ever',
#   'them',
#   'face',
#   'head',
#   'befor',
#   'place',
#   'much',
#   'last',
#   'anoth',
#   'tonight',
#   'off',
#   'show',
#   'break',
#   'start',
#   'sky',
#   'wrong',
#   'danc',
#   'dead',
#   'bring',
#   'close',
#   'fight',
#   'star',
#   'kill',
#   'high',
#   'ooh',
#   'ride',
#   'street',
#   'bodi',
#   'told',
#   'first',
#   'beat',
#   'broken',
#   'game',
#   'fine',
#   'soon',
#   'rest',
#   'empti',
#   'pretti',
#   'tire',
#   'til',
#   'felt',
#   'push',
#   'drop',
#   'bout',
#   'bone',
#   'both',
#   'shut',
#   'stranger',
#   'note',
#   'candi',
#   'corps',
#   'ought',
#   'alley',
#   'blanket',
#   'ambit',
#   'gown'],
#  'TRAACFV128F935E50B': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'in',
#   'my',
#   'of',
#   'your',
#   'that',
#   'we',
#   'am',
#   'will',
#   'be',
#   'have',
#   'so',
#   'but',
#   'just',
#   'when',
#   'now',
#   'they',
#   'down',
#   'she',
#   'see',
#   'he',
#   'feel',
#   'want',
#   'would',
#   'as',
#   'babi',
#   'by',
#   'her',
#   'thing',
#   'think',
#   'littl',
#   'said',
#   'hold',
#   'word',
#   'tonight',
#   'show',
#   'must',
#   'kiss',
#   'hate',
#   'arm',
#   'morn',
#   'em',
#   'music',
#   'fade',
#   'readi',
#   'crazi',
#   'such',
#   'laugh',
#   'went',
#   'bed',
#   'ring',
#   'mama',
#   'lip',
#   'both',
#   'daddi',
#   'd',
#   'poor',
#   'complet',
#   'diamond',
#   'pack',
#   'john',
#   'sayin',
#   'posit',
#   'steadi',
#   'wed',
#   'flip',
#   'jame',
#   'peak',
#   'faint',
#   'ladder',
#   'husband'],
#  'TRAACHN128F1489601': ['i',
#   'the',
#   'you',
#   'and',
#   'a',
#   'it',
#   'not',
#   'is',
#   'of',
#   'your',
#   'on',
#   'we',
#   'am',
#   'be',
#   'have',
#   'so',
#   'this',
#   'with',
#   'just',
#   'like',
#   'time',
#   'one',
#   'never',
#   'from',
#   'say',
#   'life',
#   'back',
#   'could',
#   'look',
#   'where',
#   'world',
#   'been',
#   'again',
#   'onli',
#   'wo',
#   'were',
#   'end',
#   'last',
#   'stop',
#   'off',
#   'peopl',
#   'made',
#   'start',
#   'should',
#   'far',
#   'yes',
#   'wish',
#   'onc',
#   'might',
#   'round',
#   'road',
#   'trust',
#   'send',
#   'brain',
#   'exist',
#   'track',
#   'problem',
#   'band',
#   'singl',
#   'messag',
#   'bend',
#   'ran',
#   'illus',
#   'x4',
#   'list',
#   'wrist',
#   'vibe',
#   'solv',
#   'conclus'],
#  'TRAACIE128F428495B': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'are',
#   'all',
#   'for',
#   'no',
#   'love',
#   'so',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'like',
#   'can',
#   'come',
#   'there',
#   'up',
#   'one',
#   'was',
#   'if',
#   'never',
#   'from',
#   'let',
#   'say',
#   'ca',
#   'yeah',
#   'by',
#   'who',
#   'too',
#   'well',
#   'his',
#   'some',
#   'over',
#   'said',
#   'head',
#   'someth',
#   'much',
#   'these',
#   'better',
#   'off',
#   'start',
#   'song',
#   'talk',
#   'true',
#   'fuck',
#   'two',
#   'done',
#   'today',
#   'hate',
#   'truth',
#   'ani',
#   'dan',
#   'sit',
#   'room',
#   's',
#   'whole',
#   't',
#   'power',
#   'bleed',
#   'brother',
#   '2',
#   'belong',
#   'damn',
#   'rule',
#   'finger',
#   'storm',
#   '1',
#   'vers',
#   'escap',
#   'famili',
#   'broke',
#   'small',
#   'bridg',
#   'stick',
#   'don',
#   'dare',
#   'pure',
#   'pop',
#   'drum',
#   'youth',
#   'certain',
#   'tabl',
#   'j',
#   'hook',
#   'motherfuck',
#   'enjoy',
#   'clown',
#   'except',
#   'bass',
#   'joe',
#   'sacr',
#   'common',
#   'p',
#   'violent',
#   'jam',
#   'pearl',
#   'jealous',
#   'mike',
#   'dedic',
#   'tore',
#   'outro',
#   'bunch',
#   'symbol'],
#  'TRAACIR128F42963AC': ['the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'so',
#   'this',
#   'but',
#   'with',
#   'just',
#   'time',
#   'there',
#   'go',
#   'up',
#   'down',
#   'was',
#   'never',
#   'he',
#   'let',
#   'as',
#   'at',
#   'away',
#   'life',
#   'by',
#   'look',
#   'eye',
#   'been',
#   'through',
#   'give',
#   'keep',
#   'dream',
#   'us',
#   'his',
#   'fall',
#   'good',
#   'hand',
#   'hold',
#   'walk',
#   'head',
#   'word',
#   'god',
#   'better',
#   'stop',
#   'thought',
#   'boy',
#   'watch',
#   'pain',
#   'same',
#   'forev',
#   'sleep',
#   'must',
#   'star',
#   'fli',
#   'shine',
#   'today',
#   'may',
#   'ground',
#   'grow',
#   'anyth',
#   'young',
#   'moon',
#   'such',
#   'earth',
#   'next',
#   'felt',
#   'thank',
#   'evil',
#   'brain',
#   'space',
#   'count',
#   'etern',
#   'realiz',
#   'mistak',
#   'suffer',
#   'tie',
#   'clean',
#   'okay',
#   'strength',
#   'ship',
#   'fix',
#   'asleep',
#   'weather',
#   'underneath',
#   'box',
#   'boot',
#   'armi',
#   'scratch',
#   'flag',
#   'bay',
#   'sheep',
#   'captain',
#   'pile',
#   'prize',
#   'cancer',
#   'stormi',
#   'correct',
#   'chin',
#   'admir',
#   '100'],
#  'TRAACJC128F934ABB5': ['i',
#   'the',
#   'you',
#   'to',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'do',
#   'are',
#   'will',
#   'no',
#   'be',
#   'have',
#   'know',
#   'with',
#   'just',
#   'when',
#   'now',
#   'time',
#   'never',
#   'from',
#   'let',
#   'make',
#   'say',
#   'as',
#   'by',
#   'look',
#   'eye',
#   'thing',
#   'been',
#   'tell',
#   'or',
#   'dream',
#   'mind',
#   'hand',
#   'noth',
#   'everi',
#   'into',
#   'hear',
#   'everyth',
#   'word',
#   'stay',
#   'friend',
#   'even',
#   'watch',
#   'same',
#   'close',
#   'rememb',
#   'ask',
#   'till',
#   'forget',
#   'els',
#   'wake',
#   'anyth',
#   'though',
#   'control',
#   'veri',
#   'power',
#   'sinc',
#   'becom',
#   'afraid',
#   'which',
#   'brain',
#   'finger',
#   'escap',
#   'hello',
#   'realiti',
#   'emot',
#   'comfort',
#   'forgotten',
#   'speed',
#   'asleep',
#   'direct',
#   'fantasi',
#   'reveal',
#   'hidden',
#   'seat',
#   'relax',
#   'heartbeat',
#   'awaken',
#   'reaction',
#   'experi',
#   'movement',
#   'hypnot',
#   'snap',
#   'distract',
#   'sleepi',
#   'spiral',
#   'tranc',
#   'effort'],
#  'TRAACPH12903CF5F14': ['the',
#   'you',
#   'and',
#   'a',
#   'in',
#   'is',
#   'your',
#   'we',
#   'will',
#   'no',
#   'so',
#   'this',
#   'with',
#   'when',
#   'come',
#   'they',
#   'see',
#   'as',
#   'our',
#   'eye',
#   'thing',
#   'live',
#   'everyth',
#   'word',
#   'much',
#   'last',
#   'play',
#   'sing',
#   'seem',
#   'dark',
#   'forev',
#   'close',
#   'mean',
#   'fade',
#   'rest',
#   'cannot',
#   'summer',
#   'winter',
#   'longer',
#   'surviv',
#   'doubl',
#   'bath',
#   'featur'],
#  'TRAACQW128F428854F': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'are',
#   'will',
#   'all',
#   'be',
#   'have',
#   'love',
#   'so',
#   'but',
#   'what',
#   'when',
#   'can',
#   'up',
#   'one',
#   'see',
#   'got',
#   'feel',
#   'make',
#   'way',
#   'take',
#   'as',
#   'day',
#   'back',
#   'heart',
#   'how',
#   'tri',
#   'well',
#   'everyth',
#   'stay',
#   'place',
#   'sing',
#   'break',
#   'sky',
#   'song',
#   'move',
#   'fire',
#   'star',
#   'cold',
#   'becaus',
#   'might',
#   'rise',
#   'though',
#   'past',
#   'memori',
#   'rest',
#   'child',
#   'peac',
#   'tire',
#   'near',
#   'piec',
#   'someday',
#   'wide',
#   'movi',
#   'trick'],
#  'TRAACRY12903CAF2C2': ['a',
#   'me',
#   'no',
#   'que',
#   'de',
#   'la',
#   'y',
#   'en',
#   'un',
#   'el',
#   'te',
#   'tu',
#   'se',
#   'mi',
#   'ya',
#   'si',
#   'por',
#   'lo',
#   'con',
#   'una',
#   'al',
#   'como',
#   'los',
#   'ha',
#   'air',
#   'mas',
#   'pero',
#   'nada',
#   'voy',
#   'tus',
#   'mis',
#   'nunca',
#   'sur',
#   'estoy',
#   'tanto',
#   'van',
#   'dia',
#   'entr',
#   'otra',
#   'hace',
#   'algo',
#   'luna',
#   'vece',
#   'recuerdo',
#   'sola',
#   'viento',
#   'ves',
#   'mismo',
#   'estrella',
#   'fuera',
#   'pelo',
#   'ze',
#   'hacia',
#   'bueno',
#   'deseo',
#   'llena',
#   'especi',
#   'piensa',
#   'hizo',
#   'nube',
#   'pierdo',
#   'espejo',
#   'dedo',
#   'magia'],
#  'TRAACUP128E0789C69': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'that',
#   'do',
#   'on',
#   'am',
#   'no',
#   'so',
#   'this',
#   'just',
#   'time',
#   'there',
#   'go',
#   'down',
#   'get',
#   'got',
#   'let',
#   'way',
#   'at',
#   'back',
#   'her',
#   'need',
#   'more',
#   'caus',
#   'been',
#   'tell',
#   'man',
#   'or',
#   'littl',
#   'turn',
#   'hey',
#   'much',
#   'move',
#   'sleep',
#   'line',
#   'till',
#   'ai',
#   'first',
#   'pass',
#   'learn',
#   'reach',
#   'meet',
#   'car',
#   'ladi',
#   'pick',
#   'send',
#   'fair',
#   'track',
#   'speed',
#   'paid',
#   'hurri',
#   'beer',
#   'waitin',
#   'class',
#   'station',
#   'engin',
#   'mister',
#   'chicken',
#   'third',
#   'driver',
#   'rate',
#   'railroad'],
#  'TRAACZN128F93236B1': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'on',
#   'are',
#   'am',
#   'for',
#   'be',
#   'so',
#   'but',
#   'with',
#   'like',
#   'go',
#   'up',
#   'they',
#   'was',
#   'see',
#   'never',
#   'he',
#   'feel',
#   'make',
#   'would',
#   'ca',
#   'by',
#   'need',
#   'our',
#   'look',
#   'where',
#   'who',
#   'live',
#   'tri',
#   'dream',
#   'an',
#   'some',
#   'littl',
#   'noth',
#   'everi',
#   'into',
#   'run',
#   'walk',
#   'face',
#   'head',
#   'believ',
#   'their',
#   'insid',
#   'befor',
#   'left',
#   'sun',
#   'thought',
#   'sing',
#   'realli',
#   'sky',
#   'song',
#   'watch',
#   'wrong',
#   'put',
#   'own',
#   'fuck',
#   'someon',
#   'must',
#   'kill',
#   'high',
#   'blood',
#   'behind',
#   'ride',
#   'hide',
#   'roll',
#   'lone',
#   'set',
#   'pass',
#   'under',
#   'road',
#   'rise',
#   'fill',
#   'game',
#   'water',
#   'blind',
#   'along',
#   'upon',
#   'drive',
#   'pull',
#   'peac',
#   'mother',
#   'til',
#   'kid',
#   'floor',
#   'bleed',
#   'warm',
#   'eat',
#   'pictur',
#   'nowher',
#   'space',
#   'ocean',
#   'finger',
#   'dress',
#   'lock',
#   'fate',
#   'wash',
#   'race',
#   'check',
#   'wit',
#   'wheel',
#   'prayer',
#   'besid',
#   'crash',
#   'price',
#   'guid',
#   'passion',
#   'written',
#   'shore',
#   'om',
#   'glow',
#   'bite',
#   'west',
#   'deserv',
#   'yellow',
#   'fame',
#   'chest',
#   'flag',
#   'engin',
#   'plant',
#   'sever',
#   'lane',
#   'discov',
#   'drove',
#   'chant',
#   'beam',
#   'unto',
#   'collid',
#   'purpl',
#   'immort',
#   'indian',
#   'practic',
#   'tank',
#   'gasolin',
#   'wooden',
#   'shark',
#   'clone'],
#  'TRAADAA128F92F7043': ['a',
#   'do',
#   'no',
#   'de',
#   'se',
#   'face',
#   'o',
#   'da',
#   'na',
#   'não',
#   'pra',
#   'sol',
#   'dos',
#   'dentro',
#   'luz',
#   'seu',
#   'ao',
#   'cantar',
#   'sombra',
#   'mala',
#   'quanto',
#   'são',
#   'rua',
#   'correr',
#   'nossa',
#   'lua',
#   'santo'],
#  'TRAADBN128F932D00A': ['me',
#   'que',
#   'de',
#   'la',
#   'en',
#   'un',
#   'se',
#   'le',
#   'du',
#   'je',
#   'et',
#   'les',
#   'il',
#   'qui',
#   'pass',
#   'pas',
#   'dan',
#   'mai',
#   'pour',
#   'ne',
#   'à',
#   's',
#   'rest',
#   'tout',
#   'va',
#   'bien',
#   'm',
#   'mon',
#   'au',
#   'moi',
#   'une',
#   'mal',
#   'n',
#   'sur',
#   'jai',
#   'san',
#   'quand',
#   'ou',
#   'ça',
#   'fait',
#   'l',
#   'par',
#   'march',
#   'jour',
#   'mond',
#   'brave',
#   'petit',
#   'j',
#   'fai',
#   'leur',
#   'regard',
#   'lit',
#   'terr',
#   'voir',
#   'lon',
#   'rue',
#   'autr',
#   'qu',
#   'gen',
#   'pourquoi',
#   'sonn',
#   'rout',
#   'personn',
#   'soi',
#   'villag',
#   'croi',
#   'rome',
#   'musiqu',
#   'sil',
#   'besoin',
#   'chemin',
#   'pourtant',
#   'doigt'],
#  'TRAADCQ128F93436C3': ['a',
#   'me',
#   'no',
#   'que',
#   'de',
#   'la',
#   'y',
#   'en',
#   'un',
#   'el',
#   'te',
#   'tu',
#   'se',
#   'mi',
#   'ya',
#   'yo',
#   'si',
#   'por',
#   'lo',
#   'amor',
#   'con',
#   'al',
#   'ti',
#   'para',
#   'sea',
#   'las',
#   'vida',
#   'su',
#   'ni',
#   'ser',
#   'va',
#   'más',
#   'tus',
#   'siempr',
#   'mis',
#   'nunca',
#   'tan',
#   'tiempo',
#   'tú',
#   'tanto',
#   'dond',
#   'está',
#   'corazón',
#   'era',
#   'cada',
#   'ahora',
#   'don',
#   'alma',
#   'cielo',
#   'pued',
#   'hace',
#   'vivir',
#   'sé',
#   'cruel',
#   'día',
#   'sueño',
#   'mí',
#   'aquí',
#   'hacer',
#   'voz',
#   'bis',
#   'camino',
#   'tard',
#   'pena',
#   'conmigo',
#   'fui',
#   'paso',
#   'ment',
#   'mismo',
#   'morir',
#   'destino',
#   'andar',
#   'silencio',
#   'vive',
#   'aquel',
#   'forma',
#   'volar',
#   'cuenta',
#   'negro',
#   'espera',
#   'razón',
#   'pueda',
#   'olvido',
#   'herida',
#   'cambiar',
#   'despertar',
#   'cancion',
#   'llevo',
#   'partir',
#   'doy',
#   'cuanto',
#   'sentimiento',
#   'adió',
#   'esperanza',
#   'decirt',
#   'creer',
#   'comprend',
#   'impos',
#   'secreto',
#   'quizá',
#   'eterno',
#   'pecho',
#   'iba',
#   'pude',
#   'piedra',
#   'amiga',
#   'pensamiento',
#   'escuchar',
#   'gritar',
#   'aquello'],
#  'TRAADKA12903CD2511': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'have',
#   'so',
#   'know',
#   'but',
#   'what',
#   'just',
#   'when',
#   'time',
#   'can',
#   'come',
#   'they',
#   'get',
#   'was',
#   'got',
#   'never',
#   'want',
#   'say',
#   'as',
#   'at',
#   'how',
#   'look',
#   'thing',
#   'tell',
#   'think',
#   'through',
#   'too',
#   'onli',
#   'tri',
#   'long',
#   'wanna',
#   'over',
#   'turn',
#   'noth',
#   'did',
#   'wait',
#   'home',
#   'hold',
#   'ever',
#   'believ',
#   'everyth',
#   'stay',
#   'much',
#   'stand',
#   'left',
#   'him',
#   'should',
#   'realli',
#   'hard',
#   'even',
#   'care',
#   'hope',
#   'free',
#   'blue',
#   'own',
#   'breath',
#   'door',
#   'wonder',
#   'heaven',
#   'hide',
#   'save',
#   'sure',
#   'until',
#   'sea',
#   'money',
#   'heard',
#   'though',
#   'tomorrow',
#   'earth',
#   'happen',
#   'between',
#   'pay',
#   'til',
#   'cos',
#   'phone',
#   'knock',
#   'corner',
#   'ago',
#   'danger',
#   'price',
#   'passion',
#   'tune',
#   'trap',
#   'televis',
#   'tap'],
#  'TRAADKW128E079503A': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'we',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'when',
#   'like',
#   'can',
#   'go',
#   'out',
#   'get',
#   'she',
#   'was',
#   'see',
#   'got',
#   'from',
#   'he',
#   'feel',
#   'want',
#   'make',
#   'way',
#   'say',
#   'take',
#   'would',
#   'as',
#   'at',
#   'away',
#   'life',
#   'here',
#   'could',
#   'our',
#   'look',
#   'thing',
#   'more',
#   'die',
#   'been',
#   'man',
#   'live',
#   'give',
#   'too',
#   'or',
#   'keep',
#   'wo',
#   'still',
#   'us',
#   'his',
#   'girl',
#   'find',
#   'littl',
#   'noth',
#   'light',
#   'said',
#   'alway',
#   'were',
#   'did',
#   'into',
#   'leav',
#   'had',
#   'someth',
#   'befor',
#   'stay',
#   'place',
#   'better',
#   'friend',
#   'left',
#   'him',
#   'than',
#   'tonight',
#   'off',
#   'thought',
#   'start',
#   'old',
#   'care',
#   'hope',
#   'move',
#   'gotta',
#   'far',
#   'someon',
#   'myself',
#   'mean',
#   'rememb',
#   'fli',
#   'lose',
#   'enough',
#   'togeth',
#   'mayb',
#   'work',
#   'save',
#   'arm',
#   'bodi',
#   'ai',
#   'round',
#   'late',
#   'ani',
#   'money',
#   'citi',
#   'young',
#   'lay',
#   'hous',
#   'somebodi',
#   'went',
#   'drive',
#   'car',
#   'drink',
#   'pay',
#   'kid',
#   'fast',
#   'cross',
#   'felt',
#   'mama',
#   'plan',
#   'somewher',
#   'both',
#   'belong',
#   'nowher',
#   'bit',
#   'quit',
#   'nice',
#   'buy',
#   'bar',
#   'problem',
#   'school',
#   'deal',
#   'prove',
#   'job',
#   'shoulder',
#   'wrap',
#   'bottl',
#   'ourselv',
#   'speed',
#   'drunk',
#   'anywher',
#   'bill',
#   'store',
#   'shelter',
#   'bigger',
#   'decis',
#   'ticket',
#   'zero',
#   'border',
#   'entertain',
#   'cruis',
#   'manag',
#   'market'],
#  'TRAADKZ128F149BDFF': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'not',
#   'in',
#   'my',
#   'is',
#   'do',
#   'on',
#   'we',
#   'be',
#   'have',
#   'love',
#   'know',
#   'this',
#   'with',
#   'what',
#   'when',
#   'like',
#   'now',
#   'come',
#   'there',
#   'go',
#   'one',
#   'get',
#   'was',
#   'see',
#   'got',
#   'would',
#   'at',
#   'yeah',
#   'by',
#   'her',
#   'where',
#   'more',
#   'been',
#   'an',
#   'good',
#   'hand',
#   'call',
#   'did',
#   'home',
#   'had',
#   'ever',
#   'end',
#   'ya',
#   'their',
#   'friend',
#   'left',
#   'play',
#   'chorus',
#   'fire',
#   'use',
#   'high',
#   'two',
#   'year',
#   'big',
#   'till',
#   'best',
#   'hell',
#   'hurt',
#   'nobodi',
#   'game',
#   'moon',
#   'hit',
#   'somebodi',
#   'drive',
#   'car',
#   'mother',
#   'great',
#   'perfect',
#   'bright',
#   'window',
#   'return',
#   'meant',
#   'nothin',
#   'destroy',
#   'shoot',
#   'school',
#   'ahead',
#   'few',
#   'brought',
#   'surpris',
#   'seek',
#   'bomb',
#   'outta',
#   'shape',
#   'ahh',
#   'electr',
#   'chest',
#   'dad',
#   'afternoon',
#   'grant',
#   'ol',
#   'lane',
#   'hangin',
#   'pant',
#   'base',
#   'bein',
#   'lower',
#   'shinin',
#   'sport',
#   'clutch',
#   'galaxi',
#   'ditch'],
#  'TRAADLH12903CA70EE': ['the',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'is',
#   'that',
#   'have',
#   'so',
#   'when',
#   'time',
#   'how',
#   'our',
#   'world',
#   'or',
#   'still',
#   'about',
#   'over',
#   'head',
#   'burn',
#   'care',
#   'seem',
#   'cold',
#   'mani',
#   'war',
#   'everyon',
#   'hang',
#   'sinc',
#   'rule',
#   'famili',
#   'ignor',
#   'rage',
#   'forgotten',
#   'diseas',
#   'clue',
#   'alarm',
#   'threat',
#   'nuclear'],
#  'TRAADNA128F9331246': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'not',
#   'in',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'we',
#   'am',
#   'for',
#   'no',
#   'be',
#   'just',
#   'time',
#   'come',
#   'there',
#   'oh',
#   'one',
#   'see',
#   'got',
#   'never',
#   'ca',
#   'day',
#   'by',
#   'here',
#   'night',
#   'need',
#   'eye',
#   'an',
#   'wo',
#   'some',
#   'turn',
#   'noth',
#   'light',
#   'soul',
#   'free',
#   'other',
#   'lose',
#   'help',
#   'save',
#   'after',
#   'fool',
#   'kind',
#   'money',
#   'nobodi',
#   'blind',
#   'strong',
#   'somebodi',
#   'happen',
#   'lead',
#   'trust',
#   'tight',
#   'caught',
#   'rule',
#   'weak',
#   'whatev',
#   'sell',
#   'golden',
#   'dime',
#   'dollar',
#   'hurri',
#   'rescu',
#   'cheek',
#   'ray',
#   'bop',
#   'spare',
#   'sympathi',
#   'neon',
#   'strand',
#   'hustl',
#   'tooth',
#   'beggin'],
#  'TRAADNL128F14519DF': ['i',
#   'the',
#   'you',
#   'to',
#   'me',
#   'it',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'are',
#   'am',
#   'will',
#   'for',
#   'be',
#   'love',
#   'know',
#   'with',
#   'when',
#   'come',
#   'oh',
#   'one',
#   'get',
#   'make',
#   'day',
#   'back',
#   'here',
#   'world',
#   'more',
#   'too',
#   'whi',
#   'keep',
#   'good',
#   'turn',
#   'light',
#   'into',
#   'stay',
#   'sun',
#   'true',
#   'two',
#   'enough',
#   'heaven',
#   'reason',
#   'aliv',
#   'water',
#   'great',
#   'cannot',
#   'three',
#   '&',
#   'chain',
#   'four',
#   'wine',
#   'five',
#   'seven',
#   'six',
#   'fix',
#   'nine',
#   'nah',
#   'addict',
#   'eight',
#   'meno'],
#  'TRAADNN128F42B1D94': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'not',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'be',
#   'have',
#   'know',
#   'this',
#   'but',
#   'when',
#   'like',
#   'time',
#   'up',
#   'one',
#   'she',
#   'was',
#   'if',
#   'from',
#   'make',
#   'take',
#   'would',
#   'as',
#   'babi',
#   'by',
#   'could',
#   'night',
#   'our',
#   'where',
#   'more',
#   'who',
#   'through',
#   'onli',
#   'or',
#   'over',
#   'then',
#   'call',
#   'everi',
#   'home',
#   'stay',
#   'these',
#   'better',
#   'play',
#   'should',
#   'dead',
#   'sleep',
#   'those',
#   'kill',
#   'breath',
#   'lord',
#   'onc',
#   'mayb',
#   'arm',
#   'morn',
#   'wall',
#   'matter',
#   'fill',
#   'follow',
#   'wake',
#   'aliv',
#   'lay',
#   'room',
#   'tomorrow',
#   'laugh',
#   'child',
#   'mother',
#   'lot',
#   'summer',
#   'worri',
#   'bit',
#   'finger',
#   'exist',
#   'held',
#   'bottl',
#   'victim',
#   'toe',
#   'guarante',
#   'inch',
#   'rearrang',
#   'retir'],
#  'TRAADQL128F427D281': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'on',
#   'are',
#   'am',
#   'will',
#   'all',
#   'have',
#   'love',
#   'so',
#   'know',
#   'with',
#   'when',
#   'like',
#   'time',
#   'can',
#   'go',
#   'out',
#   'down',
#   'get',
#   'she',
#   'got',
#   'from',
#   'want',
#   'make',
#   'say',
#   'take',
#   'life',
#   'back',
#   'heart',
#   'caus',
#   'gonna',
#   'die',
#   'think',
#   'tri',
#   'or',
#   'keep',
#   'wo',
#   'then',
#   'run',
#   'face',
#   'stay',
#   'better',
#   'stop',
#   'sing',
#   'name',
#   'sin',
#   'real',
#   'smile',
#   'black',
#   'blood',
#   'ride',
#   'hide',
#   'seen',
#   'hell',
#   'feet',
#   'happen',
#   'carri',
#   'gun',
#   'cross',
#   'goin',
#   'across',
#   'bone',
#   'bit',
#   'bird',
#   'shot',
#   'magic',
#   'track',
#   'stick',
#   'tongu',
#   'bare',
#   'cat',
#   'hors',
#   'weight',
#   'fat',
#   'grass',
#   'taught',
#   'suit',
#   'doubl',
#   'aim',
#   'gray',
#   'nest',
#   'freez',
#   'piss',
#   'snake',
#   'tini',
#   'pig',
#   'tragedi',
#   'thick',
#   'tail',
#   'crow',
#   'fri',
#   'sharp',
#   'vine',
#   'breast',
#   'lipstick',
#   'gotten',
#   'bean',
#   'butter',
#   'slick'],
#  'TRAADQX128F422B4CF': ['i',
#   'the',
#   'you',
#   'to',
#   'a',
#   'me',
#   'it',
#   'not',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'are',
#   'we',
#   'will',
#   'all',
#   'be',
#   'have',
#   'so',
#   'but',
#   'when',
#   'time',
#   'come',
#   'was',
#   'if',
#   'got',
#   'make',
#   'way',
#   'would',
#   'at',
#   'back',
#   'could',
#   'been',
#   'again',
#   'still',
#   'us',
#   'alway',
#   'home',
#   'ever',
#   'everyth',
#   'alon',
#   'place',
#   'friend',
#   'left',
#   'move',
#   'same',
#   'other',
#   'sin',
#   'rememb',
#   'kiss',
#   'wish',
#   'two',
#   'found',
#   'becaus',
#   'miss',
#   'forget',
#   'first',
#   'men',
#   'went',
#   'meet',
#   'mother',
#   'sinc',
#   '&',
#   'darl',
#   'read',
#   'buy',
#   'book',
#   'sore',
#   'pair',
#   'dull',
#   'twin'],
#  'TRAADSV128F42BC36A': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'your',
#   'that',
#   'do',
#   'we',
#   'will',
#   'be',
#   'have',
#   'love',
#   'so',
#   'know',
#   'this',
#   'but',
#   'just',
#   'now',
#   'time',
#   'go',
#   'get',
#   'let',
#   'way',
#   'say',
#   'would',
#   'ca',
#   'at',
#   'babi',
#   'away',
#   'heart',
#   'our',
#   'look',
#   'eye',
#   'caus',
#   'think',
#   'through',
#   'give',
#   'over',
#   'turn',
#   'then',
#   'said',
#   'alway',
#   'had',
#   'walk',
#   'stop',
#   'play',
#   'talk',
#   'mine',
#   'tear',
#   'fear',
#   'roll',
#   'fool',
#   'broken',
#   'part',
#   'game',
#   'blind',
#   'lover',
#   'lot',
#   'wear',
#   'both',
#   'dice',
#   'fals',
#   'shed',
#   'foolish',
#   'mask',
#   'masquerad'],
#  'TRAADVO128E07999E9': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'it',
#   'not',
#   'is',
#   'do',
#   'on',
#   'are',
#   'we',
#   'have',
#   'so',
#   'know',
#   'but',
#   'what',
#   'just',
#   'when',
#   'can',
#   'go',
#   'oh',
#   'one',
#   'they',
#   'down',
#   'make',
#   'as',
#   'at',
#   'away',
#   'back',
#   'our',
#   'look',
#   'world',
#   'been',
#   'tell',
#   'who',
#   'us',
#   'littl',
#   'god',
#   'last',
#   'stop',
#   'lost',
#   'without',
#   'talk',
#   'rain',
#   'star',
#   'while',
#   'mayb',
#   'wind',
#   'men',
#   'blow',
#   'king',
#   'power',
#   'sinc',
#   'blame',
#   'win',
#   'wash',
#   'simpl',
#   'toward',
#   'destin',
#   'tumbl',
#   'fragil',
#   'trial',
#   'intro',
#   'contempl'],
#  'TRAADYB128F92D7E73': ['i',
#   'the',
#   'you',
#   'and',
#   'me',
#   'it',
#   'not',
#   'my',
#   'will',
#   'for',
#   'be',
#   'love',
#   'so',
#   'know',
#   'this',
#   'with',
#   'just',
#   'can',
#   'go',
#   'one',
#   'see',
#   'feel',
#   'want',
#   'as',
#   'by',
#   'heart',
#   'how',
#   'more',
#   'onli',
#   'tri',
#   'wo',
#   'about',
#   'everi',
#   'much',
#   'lost',
#   'without',
#   'free',
#   'year',
#   'arm',
#   'goe',
#   'grow',
#   'becom',
#   'mad',
#   'somehow',
#   'imagin',
#   'sigh'],
#  'TRAADYI128E078FB38': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'love',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'when',
#   'like',
#   'now',
#   'can',
#   'come',
#   'there',
#   'up',
#   'one',
#   'they',
#   'down',
#   'get',
#   'she',
#   'see',
#   'if',
#   'got',
#   'from',
#   'he',
#   'way',
#   'take',
#   'as',
#   'ca',
#   'at',
#   'babi',
#   'yeah',
#   'y',
#   'back',
#   'by',
#   'her',
#   'how',
#   'night',
#   'need',
#   'our',
#   'eye',
#   'world',
#   'more',
#   'caus',
#   'right',
#   'tell',
#   'think',
#   'who',
#   'man',
#   'again',
#   'onli',
#   'tri',
#   'mind',
#   'us',
#   'his',
#   'some',
#   'over',
#   'then',
#   'said',
#   'did',
#   'home',
#   'walk',
#   'lie',
#   'end',
#   'cri',
#   'yo',
#   'these',
#   'last',
#   'off',
#   'show',
#   'lost',
#   'peopl',
#   'chorus',
#   'hard',
#   'even',
#   'put',
#   'own',
#   'fuck',
#   'close',
#   'star',
#   'while',
#   'high',
#   'two',
#   'onc',
#   'sound',
#   'everybodi',
#   'roll',
#   'son',
#   'ai',
#   'first',
#   'beat',
#   'money',
#   'air',
#   'fine',
#   'hit',
#   'men',
#   's',
#   'hous',
#   'went',
#   'meet',
#   'drink',
#   'cut',
#   'kid',
#   'nigga',
#   'floor',
#   'ladi',
#   'yet',
#   'hot',
#   'honey',
#   'parti',
#   'plus',
#   'brother',
#   'throw',
#   'goin',
#   'met',
#   'bone',
#   'piec',
#   '&',
#   'eat',
#   'second',
#   'jump',
#   'feed',
#   'front',
#   'safe',
#   'bar',
#   'ass',
#   'lift',
#   'treat',
#   'queen',
#   'okay',
#   'rather',
#   'tryin',
#   'mr',
#   'style',
#   'suppos',
#   'dime',
#   'par',
#   'grab',
#   'g',
#   'resist',
#   'niggaz',
#   'walkin',
#   'south',
#   'pound',
#   'suit',
#   'ima',
#   'motherfuck',
#   'favorit',
#   'toe',
#   'class',
#   'spot',
#   'w',
#   'playin',
#   'receiv',
#   'coat',
#   'cheek',
#   'whip',
#   'hop',
#   'chick',
# ...
#   'not',
#   'is',
#   'that',
#   'do',
#   'for',
#   'this',
#   'de',
#   'en',
#   'te',
#   'tu',
#   'whi',
#   'se',
#   'es',
#   'le',
#   'si',
#   'et',
#   'les',
#   'il',
#   'qui',
#   'pas',
#   'des',
#   'dan',
#   'mai',
#   'pour',
#   'ne',
#   'rest',
#   'cest',
#   'pay',
#   'nos',
#   'parti',
#   'plus',
#   'au',
#   'ce',
#   'comm',
#   'nous',
#   'ta',
#   'vie',
#   'entr',
#   'ell',
#   'grand',
#   'ou',
#   'ça',
#   'ton',
#   'fait',
#   'quon',
#   'tous',
#   'melodi',
#   'vill',
#   'sont',
#   'trop',
#   'quil',
#   'fort',
#   'cett',
#   'fruit',
#   'vent',
#   'soleil',
#   'content',
#   'gen',
#   'font',
#   'sest',
#   'peau',
#   'vieux',
#   'pluie',
#   'dautr'],
#  'TRAAGNS128E07824BD': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'do',
#   'on',
#   'are',
#   'for',
#   'no',
#   'know',
#   'with',
#   'just',
#   'come',
#   'there',
#   'they',
#   'down',
#   'get',
#   'was',
#   'got',
#   'want',
#   'here',
#   'how',
#   'where',
#   'tell',
#   'who',
#   'man',
#   'onli',
#   'keep',
#   'wo',
#   'his',
#   'some',
#   'littl',
#   'into',
#   'es',
#   'them',
#   'these',
#   'put',
#   'doe',
#   'side',
#   'rock',
#   'mayb',
#   'may',
#   'lone',
#   'ani',
#   'wall',
#   'game',
#   'ein',
#   'rest',
#   'went',
#   'noch',
#   'gave',
#   'peac',
#   'thank',
#   'eat',
#   'pictur',
#   'mein',
#   'slip',
#   'hole',
#   'ear',
#   'glass',
#   'wine',
#   'smell',
#   'poison',
#   'gettin',
#   'bitter',
#   'bet',
#   'torn',
#   'tall',
#   'offer',
#   'rot',
#   'makin',
#   'compani',
#   'coffe',
#   'rat',
#   'monday',
#   'tea',
#   'pot',
#   'chocol',
#   'plot',
#   'missin',
#   'spoil',
#   'lipstick'],
#  'TRAAGOZ128F92EB3D4': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'my',
#   'is',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'now',
#   'come',
#   'go',
#   'oh',
#   'out',
#   'see',
#   'never',
#   'feel',
#   'let',
#   'way',
#   'take',
#   'ca',
#   'at',
#   'yeah',
#   'back',
#   'heart',
#   'how',
#   'tell',
#   'think',
#   'too',
#   'tri',
#   'whi',
#   'mind',
#   'around',
#   'over',
#   'littl',
#   'turn',
#   'said',
#   'did',
#   'had',
#   'face',
#   'gone',
#   'everyth',
#   'has',
#   'insid',
#   'better',
#   'him',
#   'off',
#   'should',
#   'realli',
#   'hard',
#   'move',
#   'wrong',
#   'seem',
#   'own',
#   'someon',
#   'myself',
#   'mayb',
#   'hide',
#   'forget',
#   'understand',
#   'best',
#   'sometim',
#   'truth',
#   'els',
#   'fade',
#   'memori',
#   'strong',
#   'shake',
#   'cross',
#   'regret',
#   'remind',
#   'suppos',
#   'figur',
#   'oooh',
#   'eh',
#   'ooooh'],
#  'TRAAGPF12903CE027E': ['i',
#   'you',
#   'to',
#   'and',
#   'me',
#   'my',
#   'your',
#   'that',
#   'am',
#   'will',
#   'all',
#   'be',
#   'love',
#   'so',
#   'know',
#   'but',
#   'when',
#   'if',
#   'life',
#   'our',
#   'too',
#   'then',
#   'call',
#   'wait',
#   'hear',
#   'alon',
#   'blue',
#   'own',
#   'true',
#   'mean',
#   'clear',
#   'becom',
#   'ring',
#   'answer',
#   'dear',
#   'belong',
#   'echo',
#   'offer',
#   'refus'],
#  'TRAAGPJ128F428CD1B': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'do',
#   'on',
#   'are',
#   'am',
#   'all',
#   'no',
#   'be',
#   'have',
#   'love',
#   'so',
#   'know',
#   'just',
#   'when',
#   'like',
#   'up',
#   'they',
#   'if',
#   'never',
#   'from',
#   'say',
#   'would',
#   'as',
#   'ca',
#   'night',
#   'caus',
#   'gonna',
#   'die',
#   'right',
#   'man',
#   'too',
#   'or',
#   'whi',
#   'mind',
#   'wo',
#   'long',
#   'good',
#   'some',
#   'call',
#   'face',
#   'gone',
#   'word',
#   'place',
#   'anoth',
#   'care',
#   'move',
#   'wrong',
#   'put',
#   'free',
#   'gotta',
#   'talk',
#   'mine',
#   'fire',
#   'dead',
#   'mean',
#   'yes',
#   'smile',
#   'bad',
#   'togeth',
#   'came',
#   'ai',
#   'bed',
#   'cut',
#   'gun',
#   'stone',
#   'dog',
#   'pretend',
#   'dawn',
#   'spend',
#   'chain',
#   'ball',
#   'law',
#   'loos',
#   'poison',
#   'cruel',
#   'knife',
#   'cup',
#   'rope',
#   'leavin',
#   'shove',
#   'drank',
#   'dusk'],
#  'TRAAGSG128F92CFC6E': ['a',
#   'me',
#   'que',
#   'de',
#   'e',
#   'o',
#   'em',
#   'eu',
#   'mai',
#   'não',
#   'mas',
#   'um',
#   'nada',
#   'porqu',
#   'ver',
#   'sei',
#   'pra',
#   'dia',
#   'vai',
#   'com',
#   'só',
#   'os',
#   'amigo',
#   'nem',
#   'tard',
#   'mim',
#   'nas',
#   'ele',
#   'esperando',
#   'esperar',
#   'meus',
#   'num',
#   'fazer',
#   'sonho',
#   'isso',
#   'rua',
#   'sinto',
#   'pouco',
#   'acabar'],
#  'TRAAGTO128F1497E3C': ['i',
#   'you',
#   'and',
#   'me',
#   'it',
#   'in',
#   'your',
#   'we',
#   'am',
#   'will',
#   'know',
#   'but',
#   'what',
#   'when',
#   'time',
#   'can',
#   'see',
#   'life',
#   'again',
#   'too',
#   'light',
#   'stop',
#   'wrong',
#   'seem',
#   'touch',
#   'might',
#   'miss',
#   'sometim',
#   'learn',
#   'everyon',
#   'meet',
#   'fast'],
#  'TRAAGVM128E0784D95': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'be',
#   'have',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'when',
#   'like',
#   'now',
#   'time',
#   'can',
#   'up',
#   'they',
#   'out',
#   'down',
#   'get',
#   'see',
#   'if',
#   'never',
#   'from',
#   'he',
#   'let',
#   'make',
#   'way',
#   'say',
#   'take',
#   'ca',
#   'day',
#   'life',
#   'by',
#   'here',
#   'how',
#   'world',
#   'more',
#   'caus',
#   'gonna',
#   'man',
#   'give',
#   'onli',
#   'or',
#   'keep',
#   'mind',
#   'long',
#   'fall',
#   'about',
#   'some',
#   'hand',
#   'then',
#   'alway',
#   'did',
#   'them',
#   'face',
#   'believ',
#   'ya',
#   'their',
#   'place',
#   'last',
#   'friend',
#   'anoth',
#   'play',
#   'made',
#   'realli',
#   'chorus',
#   'pain',
#   'own',
#   'mine',
#   'dead',
#   'mean',
#   'breath',
#   'bad',
#   'sound',
#   'help',
#   'becaus',
#   'death',
#   'everybodi',
#   'may',
#   'ai',
#   'hurt',
#   'pass',
#   'ani',
#   'angel',
#   'chanc',
#   'part',
#   'sit',
#   'lay',
#   'shit',
#   'earth',
#   'rest',
#   'power',
#   'lot',
#   'sinc',
#   'kid',
#   'hour',
#   'sick',
#   'plan',
#   'mad',
#   'caught',
#   'damn',
#   'space',
#   'dress',
#   'minut',
#   'dont',
#   'spend',
#   'everyday',
#   'escap',
#   'grave',
#   'ass',
#   'vision',
#   'state',
#   'feelin',
#   'awak',
#   'taken',
#   'path',
#   'cat',
#   'doin',
#   'forgotten',
#   'victim',
#   'makin',
#   'prison',
#   'class',
#   'takin',
#   'limit',
#   'mission',
#   'burnin',
#   'normal',
#   'express',
#   'givin',
#   'inner',
#   'pair',
#   'rotten',
#   'neighbor',
#   'stray',
#   'visit',
#   'havin',
#   'turnin',
#   'lend',
#   'drama',
#   'oughta',
#   'wonderin',
#   'basement',
#   'powder'],
#  'TRAAGWV12903CF3709': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'of',
#   'that',
#   'do',
#   'are',
#   'we',
#   'am',
#   'all',
#   'for',
#   'have',
#   'know',
#   'but',
#   'what',
#   'just',
#   'when',
#   'like',
#   'now',
#   'time',
#   'up',
#   'they',
#   'get',
#   'see',
#   'never',
#   'from',
#   'want',
#   'make',
#   'would',
#   'yeah',
#   'back',
#   'could',
#   'look',
#   'been',
#   'through',
#   'live',
#   'give',
#   'tri',
#   'or',
#   'mind',
#   'about',
#   'some',
#   'turn',
#   'run',
#   'them',
#   'end',
#   'hey',
#   'someth',
#   'much',
#   'better',
#   'anoth',
#   'thought',
#   'start',
#   'should',
#   'without',
#   'bring',
#   'mean',
#   'doe',
#   'onc',
#   'togeth',
#   'yourself',
#   'hate',
#   'happi',
#   'seen',
#   'until',
#   'truth',
#   'kind',
#   'blind',
#   'along',
#   'shake',
#   'somebodi',
#   'pull',
#   'sinc',
#   'becom',
#   'known',
#   'fair',
#   'lookin',
#   'somehow',
#   'problem',
#   'curs',
#   'twice',
#   'bottom',
#   'wors',
#   'struggl',
#   'dumb',
#   'tail',
#   'ive',
#   'deaf'],
#  'TRAAGXU12903C9BE30': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'love',
#   'know',
#   'but',
#   'just',
#   'like',
#   'now',
#   'time',
#   'can',
#   'go',
#   'one',
#   'they',
#   'out',
#   'never',
#   'from',
#   'he',
#   'feel',
#   'let',
#   'way',
#   'say',
#   'as',
#   'at',
#   'babi',
#   'yeah',
#   'here',
#   'how',
#   'look',
#   'where',
#   'thing',
#   'more',
#   'caus',
#   'die',
#   'been',
#   'tell',
#   'through',
#   'too',
#   'onli',
#   'well',
#   'find',
#   'around',
#   'some',
#   'call',
#   'everi',
#   'alway',
#   'did',
#   'into',
#   'leav',
#   'walk',
#   'hear',
#   'has',
#   'alon',
#   'someth',
#   'better',
#   'left',
#   'off',
#   'lost',
#   'peopl',
#   'start',
#   'hope',
#   'seem',
#   'own',
#   'dark',
#   'other',
#   'must',
#   'year',
#   'ooh',
#   'roll',
#   'sure',
#   'goe',
#   'under',
#   'after',
#   'matter',
#   'rise',
#   'water',
#   'each',
#   'along',
#   'room',
#   'scream',
#   'control',
#   'everyon',
#   'promis',
#   'bed',
#   'skin',
#   'til',
#   'slow',
#   'clear',
#   'faith',
#   'fun',
#   'train',
#   'plan',
#   'throw',
#   'bone',
#   'second',
#   'scare',
#   'finger',
#   'comin',
#   'dri',
#   'phone',
#   'ear',
#   'paint',
#   'feelin',
#   'climb',
#   'stick',
#   'busi',
#   'reflect',
#   'grab',
#   'runnin',
#   'movin',
#   'attent',
#   'fallin',
#   'explod',
#   'exact',
#   'admit',
#   'ticket',
#   'twenti',
#   'nerv',
#   'grind',
#   'usual',
#   'deaf',
#   'swore',
#   'gear',
#   'safeti',
#   'missin',
#   'junki',
#   'ladder',
#   'wonderin',
#   'mold',
#   'rabbit',
#   'collar'],
#  'TRAAHBS128F429F76A': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'in',
#   'my',
#   'of',
#   'that',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'be',
#   'so',
#   'know',
#   'but',
#   'just',
#   'when',
#   'like',
#   'come',
#   'there',
#   'one',
#   'they',
#   'get',
#   'see',
#   'if',
#   'want',
#   'as',
#   'here',
#   'look',
#   'gonna',
#   'right',
#   'us',
#   'long',
#   'girl',
#   'wanna',
#   'littl',
#   'hand',
#   'everi',
#   'hold',
#   'ever',
#   'friend',
#   'anoth',
#   'song',
#   'real',
#   'two',
#   'mayb',
#   'mani',
#   'becaus',
#   'big',
#   'sea',
#   'su',
#   'three',
#   'cool',
#   'guy',
#   'four',
#   'yea',
#   'fish',
#   'stole',
#   'probabl',
#   'tini',
#   'screw'],
#  'TRAAHBU12903CB9E27': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'my',
#   'is',
#   'of',
#   'your',
#   'that',
#   'on',
#   'are',
#   'am',
#   'will',
#   'all',
#   'for',
#   'have',
#   'love',
#   'know',
#   'this',
#   'what',
#   'just',
#   'when',
#   'now',
#   'come',
#   'they',
#   'out',
#   'get',
#   'see',
#   'want',
#   'way',
#   'take',
#   'ca',
#   'life',
#   'look',
#   'caus',
#   'who',
#   'tri',
#   'mind',
#   'an',
#   'wo',
#   'littl',
#   'said',
#   'run',
#   'insid',
#   'chang',
#   'better',
#   'left',
#   'play',
#   'hope',
#   'tear',
#   'someon',
#   'yes',
#   'done',
#   'blood',
#   'enough',
#   'help',
#   'son',
#   'fool',
#   'blind',
#   'readi',
#   'past',
#   'scream',
#   'mother',
#   'troubl',
#   'knee',
#   'piec',
#   'slip',
#   'remain',
#   'dirti',
#   'scar',
#   'prove',
#   'trap',
#   'sugar',
#   'victim',
#   'diseas',
#   'trick',
#   'joke',
#   'whose',
#   'nose',
#   'lick',
#   'cage',
#   'rough',
#   'squeez',
#   'jive'],
#  'TRAAHCO128F14B0844': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'my',
#   'is',
#   'of',
#   'that',
#   'do',
#   'we',
#   'am',
#   'will',
#   'be',
#   'have',
#   'so',
#   'know',
#   'this',
#   'but',
#   'with',
#   'what',
#   'just',
#   'now',
#   'time',
#   'can',
#   'go',
#   'one',
#   'they',
#   'out',
#   'down',
#   'get',
#   'see',
#   'if',
#   'from',
#   'he',
#   'feel',
#   'let',
#   'say',
#   'take',
#   'would',
#   'ca',
#   'away',
#   'how',
#   'could',
#   'our',
#   'caus',
#   'tell',
#   'think',
#   'who',
#   'or',
#   'wo',
#   'still',
#   'his',
#   'turn',
#   'then',
#   'were',
#   'them',
#   'face',
#   'alon',
#   'someth',
#   'insid',
#   'word',
#   'place',
#   'him',
#   'burn',
#   'break',
#   'should',
#   'even',
#   'same',
#   'own',
#   'those',
#   'breath',
#   'fear',
#   'becaus',
#   'deep',
#   'grow',
#   'though',
#   'reach',
#   'such',
#   'wast',
#   'pull',
#   'power',
#   'tire',
#   'trust',
#   'tast',
#   'push',
#   'low',
#   'futur',
#   'flow',
#   'blame',
#   'against',
#   'sens',
#   'point',
#   'fate',
#   'forgiv',
#   'fail',
#   'somehow',
#   'choos',
#   'awak',
#   'buri',
#   'strength',
#   'decid',
#   'choic',
#   'proud',
#   'special',
#   'wont',
#   'weight',
#   'shape',
#   'crown',
#   'present',
#   'guilti',
#   'weari',
#   'loss',
#   'asham',
#   'failur',
#   'selfish',
#   'envi',
#   'shown',
#   'spite',
#   'cleans',
#   'rid',
#   'ident',
#   'virtu',
#   'combat'],
#  'TRAAHDK128F423BB26': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'is',
#   'your',
#   'that',
#   'do',
#   'are',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'love',
#   'with',
#   'like',
#   'up',
#   'one',
#   'get',
#   'if',
#   'from',
#   'want',
#   'take',
#   'would',
#   'ca',
#   'at',
#   'away',
#   'heart',
#   'here',
#   'how',
#   'look',
#   'eye',
#   'caus',
#   'onli',
#   'or',
#   'long',
#   'alway',
#   'did',
#   'hold',
#   'run',
#   'ever',
#   'face',
#   'end',
#   'cri',
#   'insid',
#   'place',
#   'anoth',
#   'peopl',
#   'hard',
#   'hope',
#   'dark',
#   'star',
#   'two',
#   'cold',
#   'blood',
#   'door',
#   'yourself',
#   'hate',
#   'hide',
#   'happi',
#   'understand',
#   'truth',
#   'follow',
#   'anyth',
#   'red',
#   'tomorrow',
#   's',
#   'lead',
#   'promis',
#   'window',
#   'second',
#   'minut',
#   'wash',
#   'mirror',
#   'reflect',
#   'total',
#   'gaze',
#   'drip',
#   'easier',
#   'fold',
#   'bedroom',
#   'balloon'],
#  'TRAAHDM128F429C0B1': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'not',
#   'my',
#   'your',
#   'on',
#   'are',
#   'be',
#   'with',
#   'can',
#   'one',
#   'down',
#   'see',
#   'never',
#   'take',
#   'life',
#   'by',
#   'how',
#   'look',
#   'more',
#   'mind',
#   'wanna',
#   'noth',
#   'alway',
#   'were',
#   'did',
#   'everyth',
#   'alon',
#   'chang',
#   'than',
#   'song',
#   'hide',
#   'save',
#   'tomorrow',
#   'tree',
#   'vow'],
#  'TRAAHEG128E07861C3': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'it',
#   'not',
#   'in',
#   'is',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'no',
#   'be',
#   'have',
#   'so',
#   'this',
#   'with',
#   'what',
#   'when',
#   'like',
#   'now',
#   'come',
#   'there',
#   'go',
#   'up',
#   'la',
#   'they',
#   'out',
#   'down',
#   'from',
#   'he',
#   'way',
#   'would',
#   'day',
#   'at',
#   'by',
#   'how',
#   'could',
#   'night',
#   'look',
#   'caus',
#   'right',
#   'tell',
#   'live',
#   'again',
#   'around',
#   'said',
#   'call',
#   'hold',
#   'run',
#   'walk',
#   'them',
#   'ya',
#   'yo',
#   'friend',
#   'new',
#   'than',
#   'play',
#   'hope',
#   'bring',
#   'fuck',
#   'cold',
#   'open',
#   'line',
#   'onc',
#   'ride',
#   'roll',
#   'son',
#   'ai',
#   'town',
#   'em',
#   'wall',
#   'air',
#   'water',
#   'citi',
#   'lay',
#   'shit',
#   'red',
#   'blow',
#   'pull',
#   'pay',
#   'hot',
#   'summer',
#   'troubl',
#   'wear',
#   'nowher',
#   'dog',
#   'build',
#   'comin',
#   'hole',
#   'radio',
#   'phone',
#   'shoe',
#   'ass',
#   'check',
#   'crack',
#   'spit',
#   'block',
#   'weather',
#   'highway',
#   'action',
#   'jack',
#   'niggaz',
#   'doctor',
#   'pound',
#   'motherfuck',
#   'clown',
#   'dick',
#   'piss',
#   'dj',
#   'callin',
#   'whip',
#   'brick',
#   'dope',
#   'funk',
#   'rob',
#   'ridin',
#   'stack',
#   'sourc',
#   'tap',
#   'fucker',
#   'duck',
#   'gear',
#   'memphi',
#   'dalla',
#   'chicago',
#   'fo',
#   'squad',
#   'stalk',
#   'kickin',
#   'beef',
#   'blunt'],
#  'TRAAHER128F92D0354': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'not',
#   'in',
#   'of',
#   'your',
#   'that',
#   'do',
#   'on',
#   'are',
#   'we',
#   'am',
#   'will',
#   'all',
#   'for',
#   'be',
#   'but',
#   'with',
#   'like',
#   'now',
#   'time',
#   'can',
#   'come',
#   'there',
#   'up',
#   'one',
#   'down',
#   'got',
#   'never',
#   'from',
#   'let',
#   'way',
#   'as',
#   'day',
#   'by',
#   'look',
#   'where',
#   'caus',
#   'been',
#   'or',
#   'whi',
#   'mind',
#   'find',
#   'some',
#   'said',
#   'home',
#   'gone',
#   'head',
#   'ya',
#   'has',
#   'hey',
#   'danc',
#   'must',
#   'sweet',
#   'rememb',
#   'star',
#   'yes',
#   'smile',
#   'cold',
#   'fli',
#   'sound',
#   'heaven',
#   'save',
#   'round',
#   'crazi',
#   'room',
#   'memori',
#   'child',
#   'slow',
#   'cool',
#   'wave',
#   'mile',
#   'share',
#   'drown',
#   'scare',
#   'longer',
#   'bar',
#   'corner',
#   'ago',
#   'chase',
#   'ship',
#   'shore',
#   'waitin',
#   'sayin',
#   'restless',
#   'callin',
#   'tellin',
#   'familiar',
#   'breakin',
#   'dreamin',
#   'pushin',
#   'jukebox'],
#  'TRAAHFR12903CA2491': ['i',
#   'the',
#   'you',
#   'to',
#   'and',
#   'a',
#   'me',
#   'my',
#   'is',
#   'your',
#   'on',
#   'for',
#   'have',
#   'love',
#   'know',
#   'just',
#   'like',
#   'feel',
#   'back',
#   'need',
#   'world',
#   'onli',
#   'dream',
#   'around',
#   'turn',
#   'alway',
#   'their',
#   'someth',
#   'than',
#   'burn',
#   'sky',
#   'watch',
#   'other',
#   'kiss',
#   'cold',
#   'fli',
#   'onc',
#   'door',
#   'miss',
#   'wind',
#   'chanc',
#   'blind',
#   'blow',
#   'secret',
#   'spirit',
#   'color',
#   'winter',
#   'bridg',
#   'mysteri',
#   'stronger',
#   'score',
#   'beam',
#   'slam',
#   'player',
#   'signal']}

# %%
conn_lyrics.close()
